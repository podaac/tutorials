# %% [markdown]
# ### Introduction to Programmatic Common Metadata Repository Search
#
# This notebook will introduce you to programmatic UAT Common Metadata Repository (CMR) search in python, using PO.DAAC Data as the example of data we're interested in. While these tutorials focus on PO.DAAC data, the same strategies and code snippets can be used for other earthdata collections.
#
# **Note, this notebook is adapted from the podaac_cmr_tutorial.ipynb, to test searching capabilities on Cloud Pathfinder data, in UAT CMR, and POCLOUD as provider. (catalina oaida 2020-06-12)**

# %% [markdown]
# ## API Documentation
#
# This tutorial is not meant to be a replacement for the official CMR documentation. Its features are well documented and that should be the first place to go for information. It can be found at https://cmr.earthdata.nasa.gov/search. Some users may find it easier to navigate the Earthdata Search interface, find data of interest, and then automate the results using scripts. We'd suggest visiting https://search.earthdata.nasa.gov/

# %% [markdown]
# ## CMR Background information
#
# CMR houses metadata for the 12 different DAACs. These come in the following forms:
#
# * Collections
# * Granules
# * Variables
# * Services
# * Visualizations
# * Tools
#
# This tutorial will focus on Collections and Granules. for more information, see the https://earthdata.nasa.gov/learn/user-resources/glossary

# %% [markdown]
# ### Collection / Dataset Series
#
# Collection of datasets sharing the same product specification. They are synonym of EO collections. They are named dataset series as they may be mapped to ‘dataset series’ according to the terminology defined in ISO 19113, ISO 19114 and ISO 19115.
#
# ### Granule
#
# The smallest aggregation of data which is independently managed (i. e. described, inventoried, retrievable). Granules may be managed as logical granules and/or physical granules. See also Scene.
#
# Note that granule is often equivalent to Data Set.
#
# ### Data Set
#
# A logically meaningful grouping or collection of similar or related data. Data having all of the same characteristics (source or class of source, processing level, resolution, etc.) but different independent variable ranges and/or responding to a specific need are normally considered part of a single data set. A data set is typically composed by products from several missions, gathered together to respond to the overall coverage or revisit requirements from a specific group of users.
#
# In the context of EO data preservation a data set consists of the data records of one mission, sensor, and product type and the associated knowledge(information, tools). See collection.

# %% [markdown]
# ## What does all of this mean?
#
# For the most part, users want to discover collections of interest to them, usually defined by parameter (Sea Surface Temperature, Ocean Winds, Sea Surface Height, etc), Level, spatial and temporal coverage, etc. Lets show an example.

# %% [markdown]
# ## Find collections by parameter

# %% [markdown]
# There's a lot going on here. First off, the url:
# ```
# https://cmr.uat.earthdata.nasa.gov/search/collections.umm_json?science_keywords[0][topic]=OCEANS
# ```
#
# The basic premise is this: We are asking for all collections (../search/collections) that fall under the **'OCEANS'** science topic as defined by GCMD. We are requesting this in the umm_json format (.umm_json). What we get back is a listing of those collections matching this.

# %%
from urllib import request
import json
import pprint

cmr_url = "https://cmr.uat.earthdata.nasa.gov/search/"

with request.urlopen(cmr_url+"collections.umm_json?science_keywords[0][topic]=OCEANS") as response:
    data = response.read()
    encoding = response.info().get_content_charset('utf-8')
    JSON_object = json.loads(data.decode(encoding))
    pp = pprint.PrettyPrinter(indent=2)
    pp.pprint(JSON_object)
# Out:
# { 'hits': 2343,
#   'items': [ { 'meta': { 'concept-id': 'C1228420197-AU_AADC',
#                          'concept-type': 'collection',
#                          'deleted': False,
#                          'format': 'application/dif+xml',
#                          'granule-count': 0,
#                          'has-formats': False,
#                          'has-spatial-subsetting': False,
#                          'has-temporal-subsetting': False,
#                          'has-transforms': False,
#                          'has-variables': False,
#                          'native-id': 'ASAC_2201_HCL_0.5',
#                          'provider-id': 'AU_AADC',
#                          'revision-date': '2019-12-11T21:58:41Z',
#                          'revision-id': 5,
#                          'user-id': 'sritz'},
#                'umm': { 'Abstract': 'These results are for the 0.5 hour '
#                                     'extraction of HCl.\n'
#                                     '\n'
#                                     'See also the metadata records for the 4 '
#                                     'hour extraction of HCl, and the time '
#                                     'trial data for 1 M HCl extractions.\n'
#                                     '\n'
#                                     'A regional survey of potential '
#                                     'contaminants in marine or estuarine '
#                                     'sediments is often one of the first steps '
#                                     'in a post-disturbance environmental '
#                                     'impact assessment. Of the many different '
#                                     'chemical extraction or digestion '
#                                     'procedures that have been proposed to '
#                                     'quantify metal contamination, partial '
#                                     'acid extractions are probably the best '
#                                     'overall compromise between selectivity, '
#                                     'sensitivity, precision, cost and '
#                                     'expediency.  The extent to which measured '
#                                     'metal concentrations relate to the '
#                                     'anthropogenic fraction that is '
#                                     'bioavailable is contentious, but is one '
#                                     'of the desired outcomes of an assessment '
#                                     'or prediction of biological impact.  As '
#                                     'part of a regional survey of metal '
#                                     "contamination associated with Australia's "
#                                     'past waste management activities in '
#                                     'Antarctica, we wanted to identify an acid '
#                                     'type and extraction protocol that would '
#                                     'allow a reasonable definition of the '
#                                     'anthropogenic bioavailable fraction for a '
#                                     'large number of samples.  From a kinetic '
#                                     'study of the 1 M HCl extraction of two '
#                                     'certified Certified Reference Materials '
#                                     '(MESS-2 and PACS-2) and two Antarctic '
#                                     'marine sediments, we concluded that a 4 '
#                                     'hour extraction time allows the '
#                                     'equilibrium dissolution of relatively '
#                                     'labile metal contaminants, but does not '
#                                     'favour the extraction of natural geogenic '
#                                     'metals.  In a regional survey of 88 '
#                                     'marine samples from the Casey Station '
#                                     'area of East Antarctica, the 4 h '
#                                     'extraction procedure correlated best with '
#                                     'biological data, and most clearly '
#                                     'identified those sediments thought to be '
#                                     'contaminated by runoff from abandoned '
#                                     'waste disposal sites.  Most importantly '
#                                     'the 4 hour extraction provided better '
#                                     'definition of the low to moderately '
#                                     'contaminated locations by picking up '
#                                     'small differences in anthropogenic metal '
#                                     'concentrations.  For the purposes of '
#                                     'inter-regional comparison, we recommend a '
#                                     '4 hour 1 M HCl acid extraction as a '
#                                     'standard method for assessing metal '
#                                     'contamination in Antarctica.\n'
#                                     '\n'
#                                     'The fields in this dataset are\n'
#                                     '\n'
#                                     'Location\n'
#                                     'Site\n'
#                                     'Replicate\n'
#                                     'Antimony\n'
#                                     'Arsenic\n'
#                                     'Cadmium\n'
#                                     'Chromium\n'
#                                     'Copper\n'
#                                     'Iron\n'
#                                     'Lead\n'
#                                     'Manganese\n'
#                                     'Nickel\n'
#                                     'Silver\n'
#                                     'Tin\n'
#                                     'Zinc',
#                         'AccessConstraints': { 'Description': 'The data are '
#                                                               'available for '
#                                                               'download from '
#                                                               'the url given '
#                                                               'below.'},
#                         'AncillaryKeywords': [ 'ANTIMONY',
#                                                'ARSENIC',
#                                                'BIOAVAILABLE METALS',
#                                                'CADMIUM',
#                                                'CHROMIUM',
#                                                'COPPER',
#                                                'IRON',
#                                                'KINETICS',
#                                                'LEAD',
#                                                'LOCATION',
#                                                'MANGANESE',
#                                                'MESS',
#                                                'MULTIVARIATE ANALYSIS',
#                                                'NICKEL',
#                                                'PACS',
#                                                'REPLICATE',
#                                                'SILVER',
#                                                'SITE',
#                                                'TIN',
#                                                'WINDMILL ISLANDS',
#                                                'ZINC'],
#                         'CollectionCitations': [ { 'Creator': 'Snape, I., '
#                                                               'Riddle, M.J., '
#                                                               'Gore, D., '
#                                                               'Stark, J.S., '
#                                                               'Scouller, R. '
#                                                               'and Stark, S.C.',
#                                                    'OnlineResource': { 'Linkage': 'https://data.aad.gov.au/metadata/records/ASAC_2201_HCL_0.5'},
#                                                    'Publisher': 'Australian '
#                                                                 'Antarctic '
#                                                                 'Data Centre',
#                                                    'ReleaseDate': '2004-08-02T00:00:00.000Z',
#                                                    'SeriesName': 'CAASM '
#                                                                  'Metadata',
#                                                    'Title': '0.5 hour 1 M HCl '
#                                                             'extraction data '
#                                                             'for the Windmill '
#                                                             'Islands marine '
#                                                             'sediments',
#                                                    'Version': '1'}],
#                         'CollectionProgress': 'COMPLETE',
#                         'ContactPersons': [ { 'ContactInformation': { 'Addresses': [ { 'City': 'Kingston',
#                                                                                        'Country': 'Australia',
#                                                                                        'PostalCode': '7050',
#                                                                                        'StateProvince': 'Tasmania',
#                                                                                        'StreetAddresses': [ 'Australian '
#                                                                                                             'Antarctic '
#                                                                                                             'Division',
#                                                                                                             '203 '
#                                                                                                             'Channel '
#                                                                                                             'Highway']}],
#                                                                       'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'ian.snape@aad.gov.au'},
#                                                                                              { 'Type': 'Fax',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3158'},
#                                                                                              { 'Type': 'Telephone',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3591'}]},
#                                               'FirstName': 'IAN',
#                                               'LastName': 'SNAPE',
#                                               'Roles': [ 'Investigator',
#                                                          'Technical Contact']},
#                                             { 'ContactInformation': { 'Addresses': [ { 'City': 'Kingston',
#                                                                                        'Country': 'Australia',
#                                                                                        'PostalCode': '7050',
#                                                                                        'StateProvince': 'Tasmania',
#                                                                                        'StreetAddresses': [ 'Australian '
#                                                                                                             'Antarctic '
#                                                                                                             'Division',
#                                                                                                             '203 '
#                                                                                                             'Channel '
#                                                                                                             'Highway']}],
#                                                                       'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'martin.riddle@aad.gov.au'},
#                                                                                              { 'Type': 'Fax',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3351'},
#                                                                                              { 'Type': 'Telephone',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3573'}]},
#                                               'FirstName': 'MARTIN',
#                                               'LastName': 'RIDDLE',
#                                               'MiddleName': 'J.',
#                                               'Roles': ['Investigator']},
#                                             { 'ContactInformation': { 'Addresses': [ { 'City': 'Kingston',
#                                                                                        'Country': 'Australia',
#                                                                                        'PostalCode': '7050',
#                                                                                        'StateProvince': 'Tasmania',
#                                                                                        'StreetAddresses': [ 'Australian '
#                                                                                                             'Antarctic '
#                                                                                                             'Division',
#                                                                                                             '203 '
#                                                                                                             'Channel '
#                                                                                                             'Highway']}],
#                                                                       'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'dave.connell@aad.gov.au'},
#                                                                                              { 'Type': 'Fax',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3351'},
#                                                                                              { 'Type': 'Telephone',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3244'}]},
#                                               'FirstName': 'DAVE',
#                                               'LastName': 'CONNELL',
#                                               'MiddleName': 'J.',
#                                               'Roles': ['Metadata Author']},
#                                             { 'ContactInformation': { 'Addresses': [ { 'City': 'Marsfield',
#                                                                                        'Country': 'Australia',
#                                                                                        'PostalCode': '2109',
#                                                                                        'StateProvince': 'New '
#                                                                                                         'South '
#                                                                                                         'Wales',
#                                                                                        'StreetAddresses': [ 'Department '
#                                                                                                             'of '
#                                                                                                             'Physical '
#                                                                                                             'Geography',
#                                                                                                             'Macquarie '
#                                                                                                             'University']}],
#                                                                       'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'damian.gore@mq.edu.au'},
#                                                                                              { 'Type': 'Fax',
#                                                                                                'Value': '+61 '
#                                                                                                         '2 '
#                                                                                                         '9850 '
#                                                                                                         '8420'},
#                                                                                              { 'Type': 'Telephone',
#                                                                                                'Value': '+61 '
#                                                                                                         '2 '
#                                                                                                         '9850 '
#                                                                                                         '8391'}]},
#                                               'FirstName': 'DAMIAN',
#                                               'LastName': 'GORE',
#                                               'Roles': ['Investigator']},
#                                             { 'ContactInformation': { 'Addresses': [ { 'City': 'Kingston',
#                                                                                        'Country': 'Australia',
#                                                                                        'PostalCode': '7050',
#                                                                                        'StateProvince': 'Tasmania',
#                                                                                        'StreetAddresses': [ 'Australian '
#                                                                                                             'Antarctic '
#                                                                                                             'Division',
#                                                                                                             '203 '
#                                                                                                             'Channel '
#                                                                                                             'Highway']}],
#                                                                       'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'jonny.stark@aad.gov.au'},
#                                                                                              { 'Type': 'Fax',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3158'},
#                                                                                              { 'Type': 'Telephone',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3589'}]},
#                                               'FirstName': 'JONATHAN',
#                                               'LastName': 'STARK',
#                                               'MiddleName': 'SEAN',
#                                               'Roles': ['Investigator']},
#                                             { 'ContactInformation': { 'Addresses': [ { 'City': 'Kingston',
#                                                                                        'Country': 'Australia',
#                                                                                        'PostalCode': '7050',
#                                                                                        'StateProvince': 'Tasmania',
#                                                                                        'StreetAddresses': [ 'Australian '
#                                                                                                             'Antarctic '
#                                                                                                             'Division',
#                                                                                                             '203 '
#                                                                                                             'Channel '
#                                                                                                             'Highway']}],
#                                                                       'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'beck.scouller@aad.gov.au'}]},
#                                               'FirstName': 'REBECCA',
#                                               'LastName': 'SCOULLER',
#                                               'Roles': [ 'Investigator',
#                                                          'Technical Contact']},
#                                             { 'ContactInformation': { 'Addresses': [ { 'City': 'Kingston',
#                                                                                        'Country': 'Australia',
#                                                                                        'PostalCode': '7050',
#                                                                                        'StateProvince': 'Tasmania',
#                                                                                        'StreetAddresses': [ 'Australian '
#                                                                                                             'Antarctic '
#                                                                                                             'Division',
#                                                                                                             '203 '
#                                                                                                             'Channel '
#                                                                                                             'Highway']}],
#                                                                       'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'scott.stark@aad.gov.au'},
#                                                                                              { 'Type': 'Fax',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3351'},
#                                                                                              { 'Type': 'Telephone',
#                                                                                                'Value': '+61 '
#                                                                                                         '3 '
#                                                                                                         '6232 '
#                                                                                                         '3169'}]},
#                                               'FirstName': 'SCOTT',
#                                               'LastName': 'STARK',
#                                               'MiddleName': 'CHARLES',
#                                               'Roles': ['Investigator']}],
#                         'DOI': {'DOI': 'doi:10.4225/15/5747A30D1F767'},
#                         'DataCenters': [ { 'ContactInformation': { 'RelatedUrls': [ { 'Type': 'HOME '
#                                                                                               'PAGE',
#                                                                                       'URL': 'http://data.aad.gov.au',
#                                                                                       'URLContentType': 'DataCenterURL'}]},
#                                            'ContactPersons': [ { 'ContactInformation': { 'Addresses': [ { 'City': 'Kingston',
#                                                                                                           'Country': 'Australia',
#                                                                                                           'PostalCode': '7050',
#                                                                                                           'StateProvince': 'Tasmania',
#                                                                                                           'StreetAddresses': [ 'Australian '
#                                                                                                                                'Antarctic '
#                                                                                                                                'Division',
#                                                                                                                                '203 '
#                                                                                                                                'Channel '
#                                                                                                                                'Highway']}],
#                                                                                          'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                                   'Value': 'metadata@aad.gov.au'},
#                                                                                                                 { 'Type': 'Fax',
#                                                                                                                   'Value': '+61 '
#                                                                                                                            '3 '
#                                                                                                                            '6232 '
#                                                                                                                            '3351'},
#                                                                                                                 { 'Type': 'Telephone',
#                                                                                                                   'Value': '+61 '
#                                                                                                                            '3 '
#                                                                                                                            '6232 '
#                                                                                                                            '3244'}]},
#                                                                  'FirstName': 'DATA '
#                                                                               'OFFICER',
#                                                                  'LastName': 'AADC',
#                                                                  'Roles': [ 'Data '
#                                                                             'Center '
#                                                                             'Contact']}],
#                                            'LongName': 'Australian Antarctic '
#                                                        'Data Centre, Australia',
#                                            'Roles': ['ARCHIVER', 'DISTRIBUTOR'],
#                                            'ShortName': 'AU/AADC'}],
#                         'DataLanguage': 'eng',
#                         'DirectoryNames': [ {'ShortName': 'AMD/AU'},
#                                             {'ShortName': 'CEOS'},
#                                             {'ShortName': 'AMD'}],
#                         'EntryTitle': '0.5 hour 1 M HCl extraction data for '
#                                       'the Windmill Islands marine sediments',
#                         'ISOTopicCategories': [ 'ENVIRONMENT',
#                                                 'GEOSCIENTIFIC INFORMATION',
#                                                 'OCEANS'],
#                         'LocationKeywords': [ { 'Category': 'CONTINENT',
#                                                 'DetailedLocation': 'Windmill '
#                                                                     'Islands',
#                                                 'Type': 'ANTARCTICA'},
#                                               { 'Category': 'GEOGRAPHIC REGION',
#                                                 'Type': 'POLAR'}],
#                         'MetadataDates': [ { 'Date': '2004-07-30T00:00:00.000Z',
#                                              'Type': 'CREATE'},
#                                            { 'Date': '2017-04-26T00:00:00.000Z',
#                                              'Type': 'UPDATE'}],
#                         'Platforms': [ { 'Instruments': [ { 'ShortName': 'SEDIMENT '
#                                                                          'CORERS'}],
#                                          'ShortName': 'Not provided'},
#                                        {'ShortName': 'LABORATORY'},
#                                        {'ShortName': 'FIELD SURVEYS'}],
#                         'ProcessingLevel': {'Id': 'Not provided'},
#                         'PublicationReferences': [ { 'Author': 'Snape, I., '
#                                                                'Scouller, '
#                                                                'R.C., Stark, '
#                                                                'S.C., Stark, '
#                                                                'J., Riddle, '
#                                                                'M.J., Gore, '
#                                                                'D.B.',
#                                                      'DOI': { 'DOI': 'doi:10.1016/j.chemosphere.2004.05.042'},
#                                                      'Issue': '6',
#                                                      'Pages': '491-504',
#                                                      'PublicationDate': '2004-01-01T00:00:00.000Z',
#                                                      'Series': 'Chemosphere',
#                                                      'Title': 'Characterisation '
#                                                               'of the dilute '
#                                                               'HCl extraction '
#                                                               'method for the '
#                                                               'identification '
#                                                               'of metal '
#                                                               'contamination '
#                                                               'in Antarctic '
#                                                               'marine '
#                                                               'sediments',
#                                                      'Volume': '57'}],
#                         'Quality': 'The dates provided in temporal coverage '
#                                    'are approximate only.  Years are correct.\n'
#                                    '\n'
#                                    'See the referenced paper for full details '
#                                    'on steps taken to ensure quality of data.\n'
#                                    '\n'
#                                    'To assess extraction efficiency for a '
#                                    'range of sediment types, four marine '
#                                    'sediments were analysed in detail.  Two '
#                                    'international certified reference '
#                                    'materials (CRMs) and two '
#                                    'well-characterised Antarctic sediments '
#                                    'were chosen to compare and contrast '
#                                    'moderately to strongly contaminated '
#                                    'samples (based on total metal digest), '
#                                    'with clean samples of similar matrices.  '
#                                    'One CRM was an uncontaminated continental '
#                                    'shelf mud (MESS-2), and the other a '
#                                    'contaminated harbour mud (PACS-2) (NRCC, '
#                                    '2002).  The two Antarctic sediments were '
#                                    'collected as part of a regional '
#                                    'hierarchical survey (Stark et al., 2003).  '
#                                    'One Antarctic sample was from an area of '
#                                    'known metal pollution in Brown Bay (BB), '
#                                    "which is adjacent to the 'Old' Casey "
#                                    'Station waste disposal site (Snape et al., '
#                                    '2001; Stark et al., 2003).  The second '
#                                    'Antarctic sample was from a non-impacted '
#                                    "control site from O'Brien Bay (OBB), 3 km "
#                                    'south of Casey Station and the disposal '
#                                    'site (Fig. 1).  The Antarctic samples, OBB '
#                                    'and BB, have similar matrices, proportions '
#                                    'of mud (less than 63 microns; 19% and 22% '
#                                    'respectively) and total organic carbon '
#                                    'contents (1.9% and 2.3% respectively). '
#                                    'Both MESS and PACS are sieved, homogenised '
#                                    'and dried CRMs that have been ground to '
#                                    '~50 microns (NRCC, 2002).  In contrast, '
#                                    'OBB and BB were only sieved to less than 2 '
#                                    'mm, thereby removing only the very largest '
#                                    'particles (less than or equal to 3%).  The '
#                                    'Antarctic samples were collected using '
#                                    'acid-washed PVC coring tubes.  The samples '
#                                    'were kept frozen at -20 degrees C until '
#                                    'wet-sieved with a small amount of clean '
#                                    'filtered (0.45 microns cellulose nitrate) '
#                                    "O'Brien Bay seawater through 2 mm nylon "
#                                    'mesh held in a plastic sieve unit.  The '
#                                    'sediments were then oven-dried to constant '
#                                    'weight at 103 degrees C (Loring and '
#                                    'Rantala 1992), and stored in Nalgene HDPE '
#                                    'bottles until analysis.',
#                         'RelatedUrls': [ { 'Description': 'Download point for '
#                                                           'the data',
#                                            'Type': 'GET DATA',
#                                            'URL': 'http://data.aad.gov.au/aadc/portal/download_file.cfm?file_id=1677',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'Public information '
#                                                           'for ASAC project '
#                                                           '2201',
#                                            'Type': 'PROJECT HOME PAGE',
#                                            'URL': 'https://secure3.aad.gov.au/proms/public/projects/report_project_public.cfm?project_no=2201',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Description': 'Citation reference '
#                                                           'for this metadata '
#                                                           'record and dataset',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'http://data.aad.gov.au/aadc/metadata/citation.cfm?entry_id=ASAC_2201_HCL_0.5',
#                                            'URLContentType': 'PublicationURL'}],
#                         'ScienceKeywords': [ { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ENVIRONMENTAL IMPACTS',
#                                                'Topic': 'HUMAN DIMENSIONS',
#                                                'VariableLevel1': 'HEAVY METALS '
#                                                                  'CONCENTRATION'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'MARINE SEDIMENTS',
#                                                'Topic': 'OCEANS'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'MARINE SEDIMENTS',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'SEDIMENT '
#                                                                  'CHEMISTRY'}],
#                         'ShortName': 'ASAC_2201_HCL_0.5',
#                         'SpatialExtent': { 'GranuleSpatialRepresentation': 'NO_SPATIAL',
#                                            'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 110.0,
#                                                                                                                 'NorthBoundingCoordinate': -66.0,
#                                                                                                                 'SouthBoundingCoordinate': -66.0,
#                                                                                                                 'WestBoundingCoordinate': 110.0}],
#                                                                                       'CoordinateSystem': 'CARTESIAN'}},
#                                            'SpatialCoverageType': 'HORIZONTAL'},
#                         'TemporalExtents': [ { 'RangeDateTimes': [ { 'BeginningDateTime': '1997-10-01T00:00:00.000Z',
#                                                                      'EndingDateTime': '1999-03-31T23:59:59.999Z'}]}],
#                         'UseConstraints': { 'Description': { 'Description': 'This '
#                                                                             'data '
#                                                                             'set '
#                                                                             'conforms '
#                                                                             'to '
#                                                                             'the '
#                                                                             'CCBY '
#                                                                             'Attribution '
#                                                                             'License\n'
#                                                                             '(http://creativecommons.org/licenses/by/4.0/).\n'
#                                                                             '\n'
#                                                                             'Please '
#                                                                             'follow '
#                                                                             'instructions '
#                                                                             'listed '
#                                                                             'in '
#                                                                             'the '
#                                                                             'citation '
#                                                                             'reference '
#                                                                             'provided '
#                                                                             'at '
#                                                                             'http://data.aad.gov.au/aadc/metadata/citation.cfm?entry_id=ASAC_2201_HCL_0.5 '
#                                                                             'when '
#                                                                             'using '
#                                                                             'these '
#                                                                             'data.'}},
#                         'Version': '1'}},
#              { 'meta': { 'concept-id': 'C1226767973-AU_AADC',
#                          'concept-type': 'collection',
#                          'deleted': False,
#                          'format': 'application/dif+xml',
#                          'granule-count': 0,
#                          'has-formats': False,
#                          'has-spatial-subsetting': False,
#                          'has-temporal-subsetting': False,
#                          'has-transforms': False,
#                          'has-variables': False,
#                          'native-id': '200708_CEAMARC_CASO_TRACE_ELEMENT_SAMPLES',
#                          'provider-id': 'AU_AADC',
#                          'revision-date': '2019-12-11T21:57:37Z',
#                          'revision-id': 17,
#                          'user-id': 'sritz'},
#                'umm': { 'Abstract': 'We collected surface seawater samples '
#                                     'using trace clean 1L Nalgene bottles on '
#                                     'the end of a long bamboo pole.   We will '
#                                     'analyse these samples for trace '
#                                     'elements.  Iron is the element of highest '
#                                     'interest to our group.  We will determine '
#                                     'dissolved iron and total dissolvable iron '
#                                     'concentrations.  \n'
#                                     '\n'
#                                     'Samples collected from 7 sites:  \n'
#                                     'Sites 1, 2, 3, 4 were a transect '
#                                     'perpendicular to the edge of the iceberg '
#                                     'to try and determine if there is a iron '
#                                     'concentration gradient relative to the '
#                                     'iceberg.  \n'
#                                     'Sites 4, 5, 6 were along the edge of the '
#                                     'iceberg to determine if there is any '
#                                     'spatial variability along the iceberg '
#                                     'edge. \n'
#                                     'Site 7 was away from the iceberg to '
# ...
#                                                                                       'URL': 'http://data.aad.gov.au',
#                                                                                       'URLContentType': 'DataCenterURL'}]},
#                                            'ContactPersons': [ { 'ContactInformation': { 'Addresses': [ { 'City': 'Kingston',
#                                                                                                           'Country': 'Australia',
#                                                                                                           'PostalCode': '7050',
#                                                                                                           'StateProvince': 'Tasmania',
#                                                                                                           'StreetAddresses': [ 'Australian '
#                                                                                                                                'Antarctic '
#                                                                                                                                'Division',
#                                                                                                                                '203 '
#                                                                                                                                'Channel '
#                                                                                                                                'Highway']}],
#                                                                                          'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                                   'Value': 'metadata@aad.gov.au'},
#                                                                                                                 { 'Type': 'Fax',
#                                                                                                                   'Value': '+61 '
#                                                                                                                            '3 '
#                                                                                                                            '6232 '
#                                                                                                                            '3351'},
#                                                                                                                 { 'Type': 'Telephone',
#                                                                                                                   'Value': '+61 '
#                                                                                                                            '3 '
#                                                                                                                            '6232 '
#                                                                                                                            '3244'}]},
#                                                                  'FirstName': 'DATA '
#                                                                               'OFFICER',
#                                                                  'LastName': 'AADC',
#                                                                  'Roles': [ 'Data '
#                                                                             'Center '
#                                                                             'Contact']}],
#                                            'LongName': 'Australian Antarctic '
#                                                        'Data Centre, Australia',
#                                            'Roles': ['ARCHIVER', 'DISTRIBUTOR'],
#                                            'ShortName': 'AU/AADC'}],
#                         'DataLanguage': 'eng',
#                         'DirectoryNames': [ {'ShortName': 'AMD'},
#                                             {'ShortName': 'AMD/AU'},
#                                             {'ShortName': 'CEOS'},
#                                             {'ShortName': 'ACE/CRC'}],
#                         'EntryTitle': '3-D mapping of sea ice draft with an '
#                                       'autonomous underwater vehicle',
#                         'ISOTopicCategories': ['ENVIRONMENT', 'OCEANS'],
#                         'LocationKeywords': [ { 'Category': 'OCEAN',
#                                                 'Type': 'SOUTHERN OCEAN'},
#                                               { 'Category': 'CONTINENT',
#                                                 'Type': 'ANTARCTICA'},
#                                               { 'Category': 'GEOGRAPHIC REGION',
#                                                 'Type': 'POLAR'}],
#                         'MetadataAssociations': [{'EntryId': 'SIPEX_II'}],
#                         'MetadataDates': [ { 'Date': '2013-01-09T00:00:00.000Z',
#                                              'Type': 'CREATE'},
#                                            { 'Date': '2017-11-06T00:00:00.000Z',
#                                              'Type': 'UPDATE'}],
#                         'Platforms': [ { 'LongName': 'R/V Aurora Australis',
#                                          'ShortName': 'R/V AA'},
#                                        { 'LongName': 'Autonomous Underwater '
#                                                      'Vehicles',
#                                          'ShortName': 'AUVS'}],
#                         'ProcessingLevel': {'Id': 'Not provided'},
#                         'Quality': 'The multibeam data from Station 20120926 '
#                                    'was affected by incorrect deployment '
#                                    'settings that reduced the available swath '
#                                    'and overall integrity of the final map out '
#                                    'and along a single transect of the grid.\n'
#                                    '\n'
#                                    'Ultimately there will be single MATLAB '
#                                    'files associated with each of the '
#                                    'stations. i.e. 20120926.mat\n'
#                                    '\n'
#                                    'These will contain raw and processed data '
#                                    'for\n'
#                                    'a)\tEngineering\n'
#                                    'b)\tNavigation (AUV and GRID coordinate '
#                                    'systems)\n'
#                                    'c)\tCoordinate system information\n'
#                                    'd)\tMultibeam\n'
#                                    'e)\tHyperspectral\n'
#                                    'f)\tCTD\n'
#                                    'g)\tADCP',
#                         'RelatedUrls': [ { 'Description': 'Download point for '
#                                                           'the data',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://data.aad.gov.au/eds/3463/download',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'Public information '
#                                                           'for ASAC project '
#                                                           '4073',
#                                            'Type': 'PROJECT HOME PAGE',
#                                            'URL': 'https://secure3.aad.gov.au/proms/public/projects/report_project_public.cfm?project_no=4073',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Description': 'Citation reference '
#                                                           'for this metadata '
#                                                           'record and dataset',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'http://data.aad.gov.au/aadc/metadata/citation.cfm?entry_id=SIPEX_II_AUV',
#                                            'URLContentType': 'PublicationURL'}],
#                         'ScienceKeywords': [ { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'SEA ICE',
#                                                'Topic': 'CRYOSPHERE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'SEA ICE',
#                                                'Topic': 'OCEANS'}],
#                         'ShortName': 'SIPEX_II_AUV',
#                         'SpatialExtent': { 'GranuleSpatialRepresentation': 'NO_SPATIAL',
#                                            'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 125.0,
#                                                                                                                 'NorthBoundingCoordinate': -60.0,
#                                                                                                                 'SouthBoundingCoordinate': -65.0,
#                                                                                                                 'WestBoundingCoordinate': 115.0}],
#                                                                                       'CoordinateSystem': 'CARTESIAN'}},
#                                            'SpatialCoverageType': 'HORIZONTAL'},
#                         'TemporalExtents': [ { 'RangeDateTimes': [ { 'BeginningDateTime': '2012-09-28T00:00:00.000Z',
#                                                                      'EndingDateTime': '2012-09-28T23:59:59.999Z'},
#                                                                    { 'BeginningDateTime': '2012-10-04T00:00:00.000Z',
#                                                                      'EndingDateTime': '2012-10-04T23:59:59.999Z'},
#                                                                    { 'BeginningDateTime': '2012-10-07T00:00:00.000Z',
#                                                                      'EndingDateTime': '2012-10-07T23:59:59.999Z'},
#                                                                    { 'BeginningDateTime': '2012-10-13T00:00:00.000Z',
#                                                                      'EndingDateTime': '2012-10-13T23:59:59.999Z'}]}],
#                         'UseConstraints': { 'Description': { 'Description': 'This '
#                                                                             'data '
#                                                                             'set '
#                                                                             'conforms '
#                                                                             'to '
#                                                                             'the '
#                                                                             'CCBY '
#                                                                             'Attribution '
#                                                                             'License\n'
#                                                                             '(http://creativecommons.org/licenses/by/4.0/).\n'
#                                                                             '\n'
#                                                                             'Please '
#                                                                             'follow '
#                                                                             'instructions '
#                                                                             'listed '
#                                                                             'in '
#                                                                             'the '
#                                                                             'citation '
#                                                                             'reference '
#                                                                             'provided '
#                                                                             'at '
#                                                                             'http://data.aad.gov.au/aadc/metadata/citation.cfm?entry_id=SIPEX_II_AUV '
#                                                                             'when '
#                                                                             'using '
#                                                                             'these '
#                                                                             'data.\n'
#                                                                             '\n'
#                                                                             'This '
#                                                                             'project '
#                                                                             'was '
#                                                                             'directly '
#                                                                             'cash '
#                                                                             'funded '
#                                                                             'by '
#                                                                             'the '
#                                                                             'ACECRC, '
#                                                                             'in '
#                                                                             'collaboration '
#                                                                             'with '
#                                                                             'WHOI.  '
#                                                                             'It '
#                                                                             'is '
#                                                                             'mandatory '
#                                                                             'that '
#                                                                             'both '
#                                                                             'organisations '
#                                                                             'are '
#                                                                             'represented '
#                                                                             'in '
#                                                                             'the '
#                                                                             'author-list '
#                                                                             'of '
#                                                                             'any '
#                                                                             'publication '
#                                                                             'that '
#                                                                             'directly '
#                                                                             'uses '
#                                                                             'this '
#                                                                             'data.'}},
#                         'Version': '1'}}],
#   'took': 83}

# %% [markdown]
# When last run, this was over 2000 collections! that's a lot. Let's get that down a bit...
# So next, we're now limiting the search to those with the **Oceans topic** as well as the **'Ocean Temperature'** term. To limit this further, we are only searching for collections that contain granules (data). We do this by specifying
#
# ```
# has_granules_or_cwic=true
# ```

# %%
with request.urlopen(cmr_url+"collections.umm_json?science_keywords[0][topic]=OCEANS&science_keywords[0][term]=Ocean%20Temperature&has_granules_or_cwic=true&page_size=50") as response:
    data = response.read()
    encoding = response.info().get_content_charset('utf-8')
    JSON_object = json.loads(data.decode(encoding))
    pp = pprint.PrettyPrinter(indent=2)
    pp.pprint(JSON_object)
# Out:
# { 'hits': 150,
#   'items': [ { 'meta': { 'associations': {'variables': ['V1220255769-MMT_1']},
#                          'concept-id': 'C1215726371-GES_DISC',
#                          'concept-type': 'collection',
#                          'deleted': False,
#                          'format': 'application/dif10+xml',
#                          'granule-count': 0,
#                          'has-formats': False,
#                          'has-spatial-subsetting': False,
#                          'has-temporal-subsetting': False,
#                          'has-transforms': False,
#                          'has-variables': True,
#                          'native-id': 'GSSTF_NCEP_3',
#                          'provider-id': 'GES_DISC',
#                          'revision-date': '2020-05-20T21:17:36Z',
#                          'revision-id': 38,
#                          'user-id': 'asavtche'},
#                'umm': { 'Abstract': 'These data are the Goddard '
#                                     'Satellite-based Surface Turbulent Fluxes '
#                                     'Version 3 Dataset recently produced '
#                                     'through a MEaSURES funded project led by '
#                                     'Dr. Chung-Lin Shie (UMBC/GEST, '
#                                     'NASA/GSFC), converted to HDF-EOS5 format. '
#                                     'The stewardship of this HDF-EOS5 dataset '
#                                     'is part of the MEaSUREs project. \n'
#                                     '\n'
#                                     'This is a Daily product; data are '
#                                     'projected to equidistant Grid that covers '
#                                     'the globe at 0.25x0.25 degree cell size, '
#                                     'resulting in data arrays of 1440x720 '
#                                     'size. \n'
#                                     '\n'
#                                     'The input data sets used for this recent '
#                                     'GSSTF production include the upgraded and '
#                                     'improved datasets such as the Special '
#                                     'Sensor Microwave Imager (SSM/I) Version-6 '
#                                     '(V6) product of brightness temperature '
#                                     '[Tb], total precipitable water [W], and '
#                                     'wind speed [U] produced by the Wentz of '
#                                     'Remote Sensing Systems (RSS), as well as '
#                                     'the NCEP/DOE Reanalysis-2 (R2) product of '
#                                     'sea skin temperature [SKT], 2-meter air '
#                                     'temperature [Tair], and sea level '
#                                     'pressure [SLP]. \n'
#                                     '      \n'
#                                     'The short name for this product is '
#                                     'GSSTF_NCEP.\n',
#                         'AccessConstraints': { 'Description': '\n'
#                                                               '      None\n'
#                                                               '   '},
#                         'AncillaryKeywords': [ 'fluxes',
#                                                'oceanic surface fluxes',
#                                                'latent heat flux',
#                                                'climate',
#                                                'hydrological cycle',
#                                                'hydrology',
#                                                'EOSDIS'],
#                         'ArchiveAndDistributionInformation': { 'FileDistributionInformation': [ { 'AverageFileSize': 4,
#                                                                                                   'AverageFileSizeUnit': 'MB',
#                                                                                                   'Fees': 'None',
#                                                                                                   'Format': 'HDF-EOS5',
#                                                                                                   'FormatType': 'Native',
#                                                                                                   'Media': [ 'Online '
#                                                                                                              'Archive']}]},
#                         'CollectionCitations': [ { 'Creator': 'Shie, C.-L., K. '
#                                                               'Hilburn, L. S. '
#                                                               'Chiu, R. Adler, '
#                                                               'I-I Lin, E. '
#                                                               'Nelkin, J. '
#                                                               'Ardizzone, and '
#                                                               'S. Gao',
#                                                    'DataPresentationForm': 'Digital '
#                                                                            'Science '
#                                                                            'Data',
#                                                    'Editor': 'Andrey '
#                                                              'Savtchenko',
#                                                    'IssueIdentification': 'GSSTF_NCEP_3',
#                                                    'OnlineResource': { 'Linkage': 'https://disc.gsfc.nasa.gov/datacollection/GSSTF_NCEP_3.html'},
#                                                    'Publisher': 'Goddard Earth '
#                                                                 'Sciences Data '
#                                                                 'and '
#                                                                 'Information '
#                                                                 'Services '
#                                                                 'Center (GES '
#                                                                 'DISC)',
#                                                    'ReleaseDate': '2012-08-14T00:00:00.000Z',
#                                                    'ReleasePlace': 'Greenbelt, '
#                                                                    'MD, USA',
#                                                    'SeriesName': 'GSSTF_NCEP',
#                                                    'Title': 'NCEP/DOE '
#                                                             'Reanalysis II, '
#                                                             'for GSSTF, Daily '
#                                                             'Grid V3',
#                                                    'Version': '3'}],
#                         'CollectionProgress': 'COMPLETE',
#                         'ContactPersons': [ { 'ContactInformation': { 'Addresses': [ { 'City': 'Greenbelt',
#                                                                                        'Country': 'USA',
#                                                                                        'PostalCode': '20771',
#                                                                                        'StateProvince': 'MD',
#                                                                                        'StreetAddresses': [ 'Distributed '
#                                                                                                             'Active '
#                                                                                                             'Archive '
#                                                                                                             'Center '
#                                                                                                             'Global '
#                                                                                                             'Change '
#                                                                                                             'Data '
#                                                                                                             'Center',
#                                                                                                             'Code '
#                                                                                                             '610.2',
#                                                                                                             'NASA '
#                                                                                                             'Goddard '
#                                                                                                             'Space '
#                                                                                                             'Flight '
#                                                                                                             'Center']}],
#                                                                       'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'david.s.silberstein@nasa.gov'},
#                                                                                              { 'Type': 'Telephone',
#                                                                                                'Value': '301-614-5183'},
#                                                                                              { 'Type': 'Fax',
#                                                                                                'Value': '301-614-5268'}]},
#                                               'FirstName': 'DAVID',
#                                               'LastName': 'SILBERSTEIN',
#                                               'Roles': ['Metadata Author']},
#                                             { 'ContactInformation': { 'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                'Value': 'chung-lin.shie-1@nasa.gov'}]},
#                                               'FirstName': 'CHUNG-LIN',
#                                               'LastName': 'SHIE',
#                                               'Roles': ['Investigator']}],
#                         'DOI': {'DOI': '10.5067/MEASURES/GSSTF/DATA302'},
#                         'DataCenters': [ { 'ContactGroups': [ { 'ContactInformation': { 'Addresses': [ { 'City': 'Greenbelt',
#                                                                                                          'Country': 'USA',
#                                                                                                          'PostalCode': '20771',
#                                                                                                          'StateProvince': 'MD',
#                                                                                                          'StreetAddresses': [ 'Goddard '
#                                                                                                                               'Earth '
#                                                                                                                               'Sciences '
#                                                                                                                               'Data '
#                                                                                                                               'and '
#                                                                                                                               'Information '
#                                                                                                                               'Services '
#                                                                                                                               'Center',
#                                                                                                                               'Code '
#                                                                                                                               '610.2',
#                                                                                                                               'NASA '
#                                                                                                                               'Goddard '
#                                                                                                                               'Space '
#                                                                                                                               'Flight '
#                                                                                                                               'Center']}],
#                                                                                         'ContactMechanisms': [ { 'Type': 'Email',
#                                                                                                                  'Value': 'gsfc-help-disc@lists.nasa.gov'},
#                                                                                                                { 'Type': 'Telephone',
#                                                                                                                  'Value': '301-614-5224'},
#                                                                                                                { 'Type': 'Fax',
#                                                                                                                  'Value': '301-614-5268'}]},
#                                                                 'GroupName': 'GES '
#                                                                              'DISC '
#                                                                              'HELP '
#                                                                              'DESK '
#                                                                              'SUPPORT '
#                                                                              'GROUP',
#                                                                 'Roles': [ 'Data '
#                                                                            'Center '
#                                                                            'Contact']}],
#                                            'ContactInformation': { 'RelatedUrls': [ { 'Type': 'HOME '
#                                                                                               'PAGE',
#                                                                                       'URL': 'https://disc.gsfc.nasa.gov/',
#                                                                                       'URLContentType': 'DataCenterURL'}]},
#                                            'LongName': 'Goddard Earth Sciences '
#                                                        'Data and Information '
#                                                        'Services Center '
#                                                        '(formerly Goddard '
#                                                        'DAAC), Global Change '
#                                                        'Data Center, Earth '
#                                                        'Sciences Division, '
#                                                        'Science and '
#                                                        'Exploration '
#                                                        'Directorate, Goddard '
#                                                        'Space Flight Center, '
#                                                        'NASA',
#                                            'Roles': ['ARCHIVER'],
#                                            'ShortName': 'NASA/GSFC/SED/ESD/GCDC/GESDISC',
#                                            'Uuid': '51a7f454-defc-47c2-ba6a-f95847962b7e'}],
#                         'DataDates': [ { 'Date': '2012-08-14T00:00:00.000Z',
#                                          'Type': 'CREATE'},
#                                        { 'Date': '2012-08-14T00:00:00.000Z',
#                                          'Type': 'UPDATE'}],
#                         'DataLanguage': 'eng',
#                         'EntryTitle': 'NCEP/DOE Reanalysis II, for GSSTF, 0.25 '
#                                       'x 0.25 deg, Daily Grid V3 (GSSTF_NCEP) '
#                                       'at GES DISC',
#                         'ISOTopicCategories': [ 'CLIMATOLOGY/METEOROLOGY/ATMOSPHERE',
#                                                 'OCEANS'],
#                         'LocationKeywords': [ { 'Category': 'GEOGRAPHIC REGION',
#                                                 'Type': 'GLOBAL OCEAN'}],
#                         'MetadataDates': [ { 'Date': '2012-05-30T00:00:00.000Z',
#                                              'Type': 'CREATE'},
#                                            { 'Date': '2019-05-20T10:36:43.000Z',
#                                              'Type': 'UPDATE'}],
#                         'Platforms': [ { 'Instruments': [ { 'ShortName': 'NOT '
#                                                                          'APPLICABLE'}],
#                                          'LongName': 'NCEP Global Forecast '
#                                                      'System',
#                                          'ShortName': 'NCEP-GFS',
#                                          'Type': 'Models/Analyses'}],
#                         'ProcessingLevel': {'Id': '3'},
#                         'Projects': [ { 'LongName': 'Making Earth System Data '
#                                                     'Records for Use in '
#                                                     'Research Environments',
#                                         'ShortName': 'MEaSUREs'}],
#                         'Quality': '\n'
#                                    '      See Related URL here for links to '
#                                    'quality-related documents\n'
#                                    '   ',
#                         'RelatedUrls': [ { 'Description': '\n'
#                                                           '      Goddard '
#                                                           'Satellite-based '
#                                                           'Surface Turbulent '
#                                                           'Fluxes (GSSTF)  Sea '
#                                                           'Surface Skin '
#                                                           'Temperature '
#                                                           'NCEP/DOE Reanalysis '
#                                                           'II 1 x 1 degree '
#                                                           '01/01/2001 [C]\n'
#                                                           '      ',
#                                            'Type': 'GET RELATED VISUALIZATION',
#                                            'URL': 'https://docserver.gesdisc.eosdis.nasa.gov/public/project/Images/GSSTF_NCEP_3.png',
#                                            'URLContentType': 'VisualizationURL'},
#                                          { 'Description': 'Access the dataset '
#                                                           'landing page from '
#                                                           'the GES DISC '
#                                                           'website.',
#                                            'Type': 'DATA SET LANDING PAGE',
#                                            'URL': 'https://disc.gsfc.nasa.gov/datacollection/GSSTF_NCEP_3.html',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Description': '\n'
#                                                           '   Access the data '
#                                                           'via HTTP.\n'
#                                                           '   ',
#                                            'Subtype': 'DATA TREE',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://measures.gesdisc.eosdis.nasa.gov/data/GSSTF/GSSTF_NCEP.3',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': '\n'
#                                                           '         Use the '
#                                                           'Earthdata Search to '
#                                                           'find and retrieve '
#                                                           'data sets across '
#                                                           'multiple data '
#                                                           'centers.\n'
#                                                           '      ',
#                                            'Subtype': 'Earthdata Search',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://search.earthdata.nasa.gov/search?q=GSSTF_NCEP_3',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'Access the data via '
#                                                           'the OPeNDAP '
#                                                           'protocol.',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'USE SERVICE API',
#                                            'URL': 'https://measures.gesdisc.eosdis.nasa.gov/opendap/GSSTF/GSSTF_NCEP.3',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': '\n'
#                                                           '     README '
#                                                           'Document\n'
#                                                           '     ',
#                                            'Subtype': 'READ-ME',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://measures.gesdisc.eosdis.nasa.gov/data/GSSTF/GSSTF_NCEP.3/doc/Readme.GSSTF3.pdf',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': '\n'
#                                                           'MEaSUREs Project '
#                                                           'Home Page\n',
#                                            'Type': 'PROJECT HOME PAGE',
#                                            'URL': 'https://earthdata.nasa.gov/community/community-data-system-programs/measures-projects',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Subtype': 'ALGORITHM THEORETICAL '
#                                                       'BASIS DOCUMENT (ATBD)',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://docserver.gesdisc.eosdis.nasa.gov/public/project/MEaSUREs/GSSTF/Science_of_the_data.GSSTF3.pdf',
#                                            'URLContentType': 'PublicationURL'}],
#                         'ScienceKeywords': [ { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC PRESSURE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'SEA LEVEL '
#                                                                  'PRESSURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC '
#                                                        'TEMPERATURE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'SURFACE '
#                                                                  'TEMPERATURE',
#                                                'VariableLevel2': 'AIR '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC '
#                                                        'TEMPERATURE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'SURFACE '
#                                                                  'TEMPERATURE',
#                                                'VariableLevel2': 'SKIN '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC '
#                                                        'TEMPERATURE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'SURFACE '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WATER '
#                                                        'VAPOR',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WATER VAPOR '
#                                                                  'PROCESSES',
#                                                'VariableLevel2': 'EVAPORATION'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WATER '
#                                                        'VAPOR',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WATER VAPOR '
#                                                                  'INDICATORS',
#                                                'VariableLevel2': 'HUMIDITY'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WATER '
#                                                        'VAPOR',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WATER VAPOR '
#                                                                  'INDICATORS',
#                                                'VariableLevel2': 'TOTAL '
#                                                                  'PRECIPITABLE '
#                                                                  'WATER'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WATER '
#                                                        'VAPOR',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WATER VAPOR '
#                                                                  'INDICATORS',
#                                                'VariableLevel2': 'WATER VAPOR'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WINDS',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'SURFACE '
#                                                                  'WINDS'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WINDS',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WIND '
#                                                                  'DYNAMICS',
#                                                'VariableLevel2': 'TURBULENCE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WINDS',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WIND '
#                                                                  'DYNAMICS',
#                                                'VariableLevel2': 'WIND STRESS'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC RADIATION',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'ATMOSPHERIC '
#                                                                  'HEATING'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC RADIATION',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'HEAT FLUX'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC RADIATION',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'RADIATIVE '
#                                                                  'FLUX'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN HEAT BUDGET',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'CONDUCTION'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN HEAT BUDGET',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'EVAPORATION'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN HEAT BUDGET',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'HEAT FLUX'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN PRESSURE',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'SEA LEVEL '
#                                                                  'PRESSURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN TEMPERATURE',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'SEA SURFACE '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN WINDS',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'SURFACE '
#                                                                  'WINDS'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN WINDS',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'TURBULENCE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN WINDS',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'WIND '
#                                                                  'STRESS'}],
#                         'ShortName': 'GSSTF_NCEP',
#                         'SpatialExtent': { 'GranuleSpatialRepresentation': 'CARTESIAN',
#                                            'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': 90.0,
#                                                                                                                 'SouthBoundingCoordinate': -90.0,
#                                                                                                                 'WestBoundingCoordinate': -180.0}],
#                                                                                       'CoordinateSystem': 'CARTESIAN'},
#                                                                         'ResolutionAndCoordinateSystem': { 'HorizontalDataResolution': { 'GenericResolutions': [ { 'Unit': 'Decimal '
#                                                                                                                                                                            'Degrees',
#                                                                                                                                                                    'XDimension': 0.25,
#                                                                                                                                                                    'YDimension': 0.25}]}}}},
#                         'TemporalExtents': [ { 'EndsAtPresentFlag': False,
#                                                'RangeDateTimes': [ { 'BeginningDateTime': '1987-07-01T00:00:00.000Z',
#                                                                      'EndingDateTime': '2009-01-01T23:59:59.999Z'}]}],
#                         'UseConstraints': { 'Description': { 'Description': '\n'
#                                                                             '      '
#                                                                             'None\n'
#                                                                             '   '}},
#                         'Version': '3',
#                         'VersionDescription': 'Not provided'}},
#              { 'meta': { 'associations': { 'services': [ 'S1222531904-GES_DISC',
#                                                          'S1226843656-SCIOPSTEST',
#                                                          'S1229260641-SCIOPSTEST',
#                                                          'S1228535287-SCIOPSTEST',
#                                                          'S1233603904-EEDTEST'],
#                                            'variables': [ 'V1224729814-GES_DISC',
#                                                           'V1224729839-GES_DISC',
#                                                           'V1224729954-GES_DISC',
#                                                           'V1224729856-GES_DISC',
#                                                           'V1224352417-GES_DISC',
#                                                           'V1224729952-GES_DISC',
#                                                           'V1224729845-GES_DISC',
#                                                           'V1224729817-GES_DISC',
#                                                           'V1224729849-GES_DISC',
#                                                           'V1224729904-GES_DISC',
#                                                           'V1224352381-GES_DISC',
#                                                           'V1224729835-GES_DISC',
#                                                           'V1224729893-GES_DISC',
#                                                           'V1224729879-GES_DISC',
#                                                           'V1224352380-GES_DISC',
#                                                           'V1224729823-GES_DISC',
#                                                           'V1224729933-GES_DISC',
#                                                           'V1224729923-GES_DISC',
#                                                           'V1224729927-GES_DISC',
#                                                           'V1224729917-GES_DISC',
#                                                           'V1224729871-GES_DISC',
#                                                           'V1224729843-GES_DISC',
#                                                           'V1224729841-GES_DISC',
#                                                           'V1224729896-GES_DISC',
#                                                           'V1224352390-GES_DISC',
#                                                           'V1224352407-GES_DISC',
#                                                           'V1224729869-GES_DISC',
#                                                           'V1224352391-GES_DISC',
#                                                           'V1224729940-GES_DISC',
#                                                           'V1224729877-GES_DISC',
#                                                           'V1224729873-GES_DISC',
#                                                           'V1224352377-GES_DISC',
#                                                           'V1224729913-GES_DISC',
#                                                           'V1224729854-GES_DISC',
#                                                           'V1224729833-GES_DISC',
#                                                           'V1224729921-GES_DISC',
#                                                           'V1224729907-GES_DISC',
#                                                           'V1224729825-GES_DISC',
#                                                           'V1224729858-GES_DISC',
#                                                           'V1224352376-GES_DISC',
#                                                           'V1224352387-GES_DISC',
#                                                           'V1224352397-GES_DISC',
#                                                           'V1224729829-GES_DISC',
#                                                           'V1224352383-GES_DISC',
#                                                           'V1224729911-GES_DISC',
#                                                           'V1224729889-GES_DISC',
#                                                           'V1224729803-GES_DISC',
#                                                           'V1224729902-GES_DISC',
#                                                           'V1224729886-GES_DISC',
#                                                           'V1224352410-GES_DISC',
#                                                           'V1224729891-GES_DISC',
#                                                           'V1224729860-GES_DISC',
#                                                           'V1224729868-GES_DISC',
#                                                           'V1224729811-GES_DISC',
#                                                           'V1224352401-GES_DISC',
#                                                           'V1224729909-GES_DISC',
#                                                           'V1224729831-GES_DISC',
#                                                           'V1224729852-GES_DISC',
#                                                           'V1224729805-GES_DISC',
#                                                           'V1224729837-GES_DISC',
#                                                           'V1224729815-GES_DISC',
#                                                           'V1224729925-GES_DISC',
#                                                           'V1224729944-GES_DISC',
#                                                           'V1224352399-GES_DISC',
#                                                           'V1224729929-GES_DISC',
#                                                           'V1224729887-GES_DISC',
#                                                           'V1229552502-GES_DISC',
#                                                           'V1225970791-GES_DISC',
#                                                           'V1224729915-GES_DISC',
#                                                           'V1224729885-GES_DISC',
#                                                           'V1224352394-GES_DISC',
#                                                           'V1224729948-GES_DISC',
#                                                           'V1224729820-GES_DISC',
#                                                           'V1224352403-GES_DISC',
#                                                           'V1224729801-GES_DISC',
#                                                           'V1224729919-GES_DISC',
#                                                           'V1224729906-GES_DISC',
#                                                           'V1224729863-GES_DISC',
#                                                           'V1224729822-GES_DISC',
#                                                           'V1224352406-GES_DISC',
#                                                           'V1224352386-GES_DISC',
#                                                           'V1224729939-GES_DISC',
#                                                           'V1224729936-GES_DISC',
#                                                           'V1224729802-GES_DISC',
#                                                           'V1224352418-GES_DISC',
#                                                           'V1224352395-GES_DISC',
#                                                           'V1224729810-GES_DISC',
#                                                           'V1224729848-GES_DISC',
#                                                           'V1224729950-GES_DISC',
#                                                           'V1224352412-GES_DISC',
#                                                           'V1224729931-GES_DISC',
#                                                           'V1224729898-GES_DISC',
#                                                           'V1224729827-GES_DISC',
#                                                           'V1224729807-GES_DISC',
#                                                           'V1224729862-GES_DISC',
#                                                           'V1224729882-GES_DISC',
#                                                           'V1224729900-GES_DISC',
#                                                           'V1224729946-GES_DISC',
#                                                           'V1224729941-GES_DISC',
#                                                           'V1224729875-GES_DISC',
#                                                           'V1224352413-GES_DISC',
#                                                           'V1224729865-GES_DISC']},
#                          'concept-id': 'C1215669046-GES_DISC',
#                          'concept-type': 'collection',
#                          'deleted': False,
#                          'format': 'application/dif10+xml',
#                          'granule-count': 0,
#                          'has-formats': True,
#                          'has-spatial-subsetting': True,
#                          'has-temporal-subsetting': False,
#                          'has-transforms': False,
#                          'has-variables': True,
#                          'native-id': 'AIRX3STD_006',
#                          'provider-id': 'GES_DISC',
#                          'revision-date': '2019-12-11T18:57:08Z',
#                          'revision-id': 41,
#                          'user-id': 'cloeser1'},
#                'umm': { 'Abstract': 'The Atmospheric Infrared Sounder (AIRS) '
#                                     'is a grating spectrometer (R = 1200) '
#                                     'aboard the second Earth Observing System '
#                                     '(EOS) polar-orbiting platform, EOS Aqua. '
#                                     'In combination with the Advanced '
#                                     'Microwave Sounding Unit (AMSU) and the '
#                                     'Humidity Sounder for Brazil (HSB), AIRS '
#                                     'constitutes an innovative atmospheric '
#                                     'sounding group of visible, infrared, and '
#                                     'microwave sensors. The AIRS Level 3 Daily '
#                                     'Gridded Product contains standard '
#                                     'retrieval means, standard deviations and '
#                                     'input counts. Each file covers a temporal '
#                                     'period of 24 hours for either the '
#                                     'descending (equatorial crossing North to '
#                                     'South @1:30 AM local time) or ascending '
#                                     '(equatorial crossing South to North @1:30 '
#                                     'PM local time) orbit. The data starts at '
#                                     'the international dateline and progresses '
#                                     'westward (as do the subsequent orbits of '
#                                     'the satellite) so that neighboring '
#                                     'gridded cells of data are no more than a '
#                                     'swath of time apart (about 90 minutes). '
#                                     'The two parts of a scan line crossing the '
#                                     'dateline are included in separate L3 '
#                                     'files, according to the date, so that '
#                                     'data points in a grid box are always '
#                                     'coincident in time. The edge of the AIRS '
#                                     'Level 3 gridded cells is at the date line '
#                                     '(the 180E/W longitude boundary). When '
#                                     'plotted, this produces a map with 0 '
#                                     'degrees longitude in the center of the '
#                                     'image unless the bins are reordered. This '
#                                     'method is preferred because the left '
#                                     '(West) side of the image and the right '
#                                     '(East) side of the image contain data '
# ...
#                                                           'sets across '
#                                                           'multiple data '
#                                                           'centers from a '
#                                                           'single unified '
#                                                           'interface.',
#                                            'Subtype': 'SIMPLE SUBSET WIZARD '
#                                                       '(SSW)',
#                                            'Type': 'GOTO WEB TOOL',
#                                            'URL': 'https://disc.gsfc.nasa.gov/SSW/#keywords=AIRH3STD%20006',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'Use the Earthdata '
#                                                           'Search to find and '
#                                                           'retrieve data sets '
#                                                           'across multiple '
#                                                           'data centers.',
#                                            'Subtype': 'Earthdata Search',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://search.earthdata.nasa.gov/search?q=AIRH3STD+006',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'AIRS home page at '
#                                                           'NASA/JPL. General '
#                                                           'information on the '
#                                                           'AIRS instrument, '
#                                                           'algorithms, and '
#                                                           'other AIRS-related '
#                                                           'activities can be '
#                                                           'found.',
#                                            'Type': 'PROJECT HOME PAGE',
#                                            'URL': 'https://airs.jpl.nasa.gov/index.html',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Description': 'AIRS Documentation '
#                                                           'Page',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://disc.gsfc.nasa.gov/information/documents?title=AIRS%20Documentation',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': 'README Document',
#                                            'Subtype': 'READ-ME',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://docserver.gesdisc.eosdis.nasa.gov/repository/Mission/AIRS/3.3_ScienceDataProductDocumentation/3.3.4_ProductGenerationAlgorithms/README.AIRS_V6.pdf',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': 'AIRS Version 6 '
#                                                           'Processing Files '
#                                                           'Description '
#                                                           'Document.',
#                                            'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://docserver.gesdisc.eosdis.nasa.gov/repository/Mission/AIRS/3.3_ScienceDataProductDocumentation/3.3.4_ProductGenerationAlgorithms/V6_Released_Processing_Files_Description.pdf',
#                                            'URLContentType': 'PublicationURL'}],
#                         'ScienceKeywords': [ { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ALTITUDE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'TROPOPAUSE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC PRESSURE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'SURFACE '
#                                                                  'PRESSURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC '
#                                                        'TEMPERATURE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'SURFACE '
#                                                                  'TEMPERATURE',
#                                                'VariableLevel2': 'AIR '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC '
#                                                        'TEMPERATURE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'UPPER AIR '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WATER '
#                                                        'VAPOR',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WATER VAPOR '
#                                                                  'INDICATORS',
#                                                'VariableLevel2': 'TOTAL '
#                                                                  'PRECIPITABLE '
#                                                                  'WATER'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WATER '
#                                                        'VAPOR',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WATER VAPOR '
#                                                                  'INDICATORS',
#                                                'VariableLevel2': 'WATER VAPOR'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'CLOUDS',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'CLOUD '
#                                                                  'PROPERTIES',
#                                                'VariableLevel2': 'CLOUD '
#                                                                  'HEIGHT'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'CLOUDS',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'CLOUD '
#                                                                  'PROPERTIES',
#                                                'VariableLevel2': 'CLOUD TOP '
#                                                                  'PRESSURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'CLOUDS',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'CLOUD '
#                                                                  'PROPERTIES',
#                                                'VariableLevel2': 'CLOUD TOP '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'CLOUDS',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'CLOUD '
#                                                                  'PROPERTIES',
#                                                'VariableLevel2': 'CLOUD '
#                                                                  'VERTICAL '
#                                                                  'DISTRIBUTION'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'SURFACE RADIATIVE '
#                                                        'PROPERTIES',
#                                                'Topic': 'LAND SURFACE',
#                                                'VariableLevel1': 'EMISSIVITY'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'OCEAN TEMPERATURE',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'SEA SURFACE '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'SURFACE THERMAL '
#                                                        'PROPERTIES',
#                                                'Topic': 'LAND SURFACE',
#                                                'VariableLevel1': 'SKIN '
#                                                                  'TEMPERATURE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'AIR QUALITY',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'CARBON '
#                                                                  'MONOXIDE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ALTITUDE',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'GEOPOTENTIAL '
#                                                                  'HEIGHT'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WATER '
#                                                        'VAPOR',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WATER VAPOR '
#                                                                  'INDICATORS',
#                                                'VariableLevel2': 'HUMIDITY'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC WATER '
#                                                        'VAPOR',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'WATER VAPOR '
#                                                                  'PROFILES'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'CLOUDS',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'CLOUD '
#                                                                  'MICROPHYSICS',
#                                                'VariableLevel2': 'CLOUD LIQUID '
#                                                                  'WATER/ICE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC RADIATION',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'OUTGOING '
#                                                                  'LONGWAVE '
#                                                                  'RADIATION'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC CHEMISTRY',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'CARBON AND '
#                                                                  'HYDROCARBON '
#                                                                  'COMPOUNDS',
#                                                'VariableLevel2': 'METHANE'},
#                                              { 'Category': 'EARTH SCIENCE',
#                                                'Term': 'ATMOSPHERIC CHEMISTRY',
#                                                'Topic': 'ATMOSPHERE',
#                                                'VariableLevel1': 'OXYGEN '
#                                                                  'COMPOUNDS',
#                                                'VariableLevel2': 'OZONE'}],
#                         'ShortName': 'AIRH3STD',
#                         'SpatialExtent': { 'GranuleSpatialRepresentation': 'CARTESIAN',
#                                            'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': 90.0,
#                                                                                                                 'SouthBoundingCoordinate': -90.0,
#                                                                                                                 'WestBoundingCoordinate': -180.0}],
#                                                                                       'CoordinateSystem': 'CARTESIAN'},
#                                                                         'ResolutionAndCoordinateSystem': { 'HorizontalDataResolution': { 'GenericResolutions': [ { 'Unit': 'Decimal '
#                                                                                                                                                                            'Degrees',
#                                                                                                                                                                    'XDimension': 1,
#                                                                                                                                                                    'YDimension': 1}]}}}},
#                         'TemporalExtents': [ { 'EndsAtPresentFlag': False,
#                                                'RangeDateTimes': [ { 'BeginningDateTime': '2002-08-31T00:00:00.000Z',
#                                                                      'EndingDateTime': '2003-02-06T23:59:59.999Z'}]}],
#                         'Version': '006'}}],
#   'took': 182}

# %% [markdown]
# So we are closing in on this. Let's **add a time range** and **find some PO.DAAC Cloud (POCLOUD) data**:
# ```
# temporal=2018-01-01T10:00:00Z,2019-01-01T10:00:00Z&provider_short_name=PODAAC&processing_level_id=4
# ```
#
# We **specified a temporal range for all of 2018**, **POCLOUD as the provider**, and **level 2 data**, since it's a bit easier for us to work with.

# %%
#with request.urlopen(cmr_url+"collections.umm_json?science_keywords[0][topic]=OCEANS&science_keywords[0][term]=Ocean%20Temperature&has_granules_or_cwic=true&temporal=2018-01-01T10:00:00Z,2019-01-01T10:00:00Z&provider_short_name=PODAAC&processing_level_id=4&page_size=50") as response:
with request.urlopen(cmr_url+"collections.umm_json?science_keywords[0][topic]=OCEANS&science_keywords[0][term]=Ocean%20Temperature&has_granules_or_cwic=true&temporal=2018-01-01T10:00:00Z,2019-01-01T10:00:00Z&provider_short_name=POCLOUD&processing_level_id=2&page_size=50") as response:
    data = response.read()
    encoding = response.info().get_content_charset('utf-8')
    JSON_object = json.loads(data.decode(encoding))
    pp = pprint.PrettyPrinter(indent=2)
    pp.pprint(JSON_object)
# Out:
# { 'hits': 2,
#   'items': [ { 'meta': { 'associations': { 'services': ['S1234899453-POCLOUD'],
#                                            'variables': [ 'V1234931477-POCLOUD',
#                                                           'V1234931452-POCLOUD',
#                                                           'V1234931458-POCLOUD',
#                                                           'V1234931402-POCLOUD',
#                                                           'V1234931475-POCLOUD',
#                                                           'V1234931454-POCLOUD',
#                                                           'V1234931466-POCLOUD',
#                                                           'V1234931570-POCLOUD',
#                                                           'V1234931433-POCLOUD',
#                                                           'V1234931462-POCLOUD',
#                                                           'V1234931469-POCLOUD',
#                                                           'V1234931566-POCLOUD',
#                                                           'V1234931460-POCLOUD',
#                                                           'V1234931568-POCLOUD',
#                                                           'V1234931464-POCLOUD',
#                                                           'V1234931564-POCLOUD',
#                                                           'V1234931456-POCLOUD']},
#                          'concept-id': 'C1234724470-POCLOUD',
#                          'concept-type': 'collection',
#                          'deleted': False,
#                          'format': 'application/echo10+xml',
#                          'granule-count': 0,
#                          'has-formats': True,
#                          'has-spatial-subsetting': True,
#                          'has-temporal-subsetting': False,
#                          'has-transforms': False,
#                          'has-variables': True,
#                          'native-id': 'MODIS_A-JPL-L2P-v2019.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-05-14T23:48:46Z',
#                          'revision-id': 1,
#                          'user-id': 'nchung'},
#                'umm': { 'Abstract': 'NASA produces skin sea surface '
#                                     'temperature (SST) products from the '
#                                     'Infrared (IR) channels of the '
#                                     'Moderate-resolution Imaging '
#                                     'Spectroradiometer (MODIS) onboard the '
#                                     'Aqua satellite. Aqua was launched by NASA '
#                                     'on May 4, 2002, into a sun synchronous, '
#                                     'polar orbit with a daylight ascending '
#                                     'node at 1:30 pm, formation flying in the '
#                                     'A-train with other Earth Observation '
#                                     'Satellites (EOS), to study the global '
#                                     'dynamics of the Earth atmosphere, land '
#                                     'and oceans. MODIS captures data in 36 '
#                                     'spectral bands at a variety of spatial '
#                                     'resolutions.  Two SST products can be '
#                                     'present in these files. The first is a '
#                                     'skin SST produced for both day and night '
#                                     '(NSST) observations, derived from the '
#                                     'long wave IR 11 and 12 micron wavelength '
#                                     'channels, using a modified nonlinear SST '
#                                     'algorithm intended to provide continuity '
#                                     'of SST derived from heritage and current '
#                                     'NASA sensors. At night, a second SST '
#                                     'product is generated using the '
#                                     'mid-infrared 3.95 and 4.05 micron  '
#                                     'wavelength channels which are unique to '
#                                     'MODIS; the SST derived from these '
#                                     'measurements is identified as SST4. The '
#                                     'SST4 product has lower uncertainty, but '
#                                     'due to sun glint can only be used at '
#                                     'night. MODIS L2P SST data have a 1 km '
#                                     'spatial resolution at nadir and are '
#                                     'stored in 288 five minute granules per '
#                                     'day. Full global coverage is obtained '
#                                     'every two days, with coverage poleward of '
#                                     '32.3 degree being complete each day.  The '
#                                     'production of MODIS L2P SST files is part '
#                                     'of the Group for High Resolution Sea '
#                                     'Surface Temperature (GHRSST) project and '
#                                     'is a joint collaboration between the NASA '
#                                     'Jet Propulsion Laboratory (JPL), the NASA '
#                                     'Ocean Biology Processing Group (OBPG), '
#                                     'and the Rosenstiel School of Marine and '
#                                     'Atmospheric Science (RSMAS). Researchers '
#                                     'at RSMAS are responsible for SST '
#                                     'algorithm development, error statistics '
#                                     'and quality flagging, while the OBPG, as '
#                                     'the NASA ground data system, is '
#                                     'responsible for the production of daily '
#                                     'MODIS ocean products. JPL acquires MODIS '
#                                     'ocean granules from the OBPG and '
#                                     'reformats them to the GHRSST L2P netCDF '
#                                     'specification with complete metadata and '
#                                     'ancillary variables, and distributes the '
#                                     'data as the official Physical '
#                                     'Oceanography Data Archive (PO.DAAC) for '
#                                     'SST.  The R2019.0 supersedes the previous '
#                                     'R2014.0 datasets which can be found '
#                                     'athttps://doi.org/10.5067/GHMDA-2PJ02',
#                         'ArchiveAndDistributionInformation': { 'FileDistributionInformation': [ { 'Format': 'NETCDF',
#                                                                                                   'FormatType': 'Native'}]},
#                         'CollectionCitations': [ { 'OtherCitationDetails': 'JPL/OBPG/RSMAS, '
#                                                                            'Jet '
#                                                                            'Propulsion '
#                                                                            'Laboratory, '
#                                                                            '2020-01-15, '
#                                                                            'GHRSST '
#                                                                            'Level '
#                                                                            '2P '
#                                                                            'Global '
#                                                                            'Sea '
#                                                                            'Surface '
#                                                                            'Skin '
#                                                                            'Temperature '
#                                                                            'from '
#                                                                            'the '
#                                                                            'Moderate '
#                                                                            'Resolution '
#                                                                            'Imaging '
#                                                                            'Spectroradiometer '
#                                                                            '(MODIS) '
#                                                                            'on '
#                                                                            'the '
#                                                                            'NASA '
#                                                                            'Aqua '
#                                                                            'satellite '
#                                                                            '(GDS2), '
#                                                                            '10.5067/GHMDA-2PJ19, '
#                                                                            'Information '
#                                                                            'on '
#                                                                            'the '
#                                                                            'the '
#                                                                            'MODIS '
#                                                                            'SST '
#                                                                            'algorithm '
#                                                                            'can '
#                                                                            'be '
#                                                                            'found '
#                                                                            'in '
#                                                                            'the '
#                                                                            'following '
#                                                                            'documents: '
#                                                                            'http://modis.gsfc.nasa.gov/data/atbd/atbd_mod25.pdf '
#                                                                            'and '
#                                                                            'http://oceancolor.gsfc.nasa.gov/DOCS/modis_sst/'}],
#                         'CollectionProgress': 'NOT PROVIDED',
#                         'DOI': {'DOI': '10.5067/GHMDA-2PJ19'},
#                         'DataCenters': [ { 'Roles': ['PROCESSOR'],
#                                            'ShortName': 'Jet Propulsion '
#                                                         'Laboratory'},
#                                          { 'Roles': ['ARCHIVER'],
#                                            'ShortName': 'NASA/JPL/PODAAC'},
#                                          { 'ContactInformation': { 'ContactMechanisms': [ { 'Type': 'Primary',
#                                                                                             'Value': '305-421-4615'},
#                                                                                           { 'Type': 'Email',
#                                                                                             'Value': 'KKilpatrick@rsmas.miami.edu'}]},
#                                            'ContactPersons': [ { 'FirstName': 'Kay',
#                                                                  'LastName': 'Kilpatrick',
#                                                                  'MiddleName': 'none',
#                                                                  'Roles': [ 'Investigator']}],
#                                            'Roles': ['ARCHIVER'],
#                                            'ShortName': 'Rosenstiel School of '
#                                                         'Marine and '
#                                                         'Atmospheric Science'},
#                                          { 'ContactInformation': { 'ContactMechanisms': [ { 'Type': 'Primary',
#                                                                                             'Value': '818-393-6710'},
#                                                                                           { 'Type': 'Email',
#                                                                                             'Value': 'edward.m.armstrong@jpl.nasa.gov'}]},
#                                            'ContactPersons': [ { 'FirstName': 'Edward',
#                                                                  'LastName': 'Armstrong',
#                                                                  'MiddleName': 'none',
#                                                                  'Roles': [ 'Technical '
#                                                                             'Contact']}],
#                                            'LongName': 'Physical Oceanography '
#                                                        'Distributed Active '
#                                                        'Archive Center, Jet '
#                                                        'Propulsion Laboratory, '
#                                                        'NASA',
#                                            'Roles': ['ARCHIVER'],
#                                            'ShortName': 'Physical Oceanography '
#                                                         'Distributed Active '
#                                                         'Archive Center, Jet '
#                                                         'Propulsion '
#                                                         'Laboratory, N'}],
#                         'DataDates': [ { 'Date': '2019-12-02T22:59:24.849Z',
#                                          'Type': 'CREATE'},
#                                        { 'Date': '2019-12-02T22:59:24.849Z',
#                                          'Type': 'UPDATE'}],
#                         'EntryTitle': 'GHRSST Level 2P Global Sea Surface Skin '
#                                       'Temperature from the Moderate '
#                                       'Resolution Imaging Spectroradiometer '
#                                       '(MODIS) on the NASA Aqua satellite '
#                                       '(GDS2)',
#                         'LocationKeywords': [ { 'Category': 'GEOGRAPHIC REGION',
#                                                 'Type': 'GLOBAL'}],
#                         'MetadataDates': [ { 'Date': '2020-02-12T15:18:12.274Z',
#                                              'Type': 'UPDATE'}],
#                         'Platforms': [ { 'Characteristics': [ { 'DataType': 'FLOAT',
#                                                                 'Description': 'Nominal '
#                                                                                'period '
#                                                                                'of '
#                                                                                'a '
#                                                                                'spacecraft?s '
#                                                                                'single '
#                                                                                'revolution '
#                                                                                'on '
#                                                                                'an '
#                                                                                'orbital '
#                                                                                'plane.',
#                                                                 'Name': 'OrbitPeriod',
#                                                                 'Unit': 'Minutes',
#                                                                 'Value': '98.4'},
#                                                               { 'DataType': 'FLOAT',
#                                                                 'Description': 'Spacecraft '
#                                                                                'angular '
#                                                                                'distance '
#                                                                                'from '
#                                                                                'orbital '
#                                                                                'plane '
#                                                                                'relative '
#                                                                                'to '
#                                                                                'the '
#                                                                                'Equator.',
#                                                                 'Name': 'InclinationAngle',
#                                                                 'Unit': 'Degrees',
#                                                                 'Value': '98.1'}],
#                                          'Instruments': [ { 'Characteristics': [ { 'DataType': 'FLOAT',
#                                                                                    'Description': 'Spacecraft '
#                                                                                                   'angular '
#                                                                                                   'distance '
#                                                                                                   'from '
#                                                                                                   'orbital '
#                                                                                                   'plane '
#                                                                                                   'relative '
#                                                                                                   'to '
#                                                                                                   'the '
#                                                                                                   'Equator.',
#                                                                                    'Name': 'SwathWidth',
#                                                                                    'Unit': 'Meters',
#                                                                                    'Value': '2330.0'}],
#                                                             'LongName': 'Moderate-Resolution '
#                                                                         'Imaging '
#                                                                         'Spectroradiometer',
#                                                             'ShortName': 'MODIS'}],
#                                          'LongName': 'Earth Observing System, '
#                                                      'AQUA',
#                                          'ShortName': 'Aqua',
#                                          'Type': 'SPACECRAFT'}],
#                         'ProcessingLevel': {'Id': '2'},
#                         'Projects': [{'ShortName': 'GHRSST'}],
#                         'RelatedUrls': [ { 'Description': 'The HTTP location '
#                                                           'for the collection.',
#                                            'GetData': { 'Format': 'Not '
#                                                                   'provided',
#                                                         'MimeType': 'text/html',
#                                                         'Size': 0.0,
#                                                         'Unit': 'KB'},
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://data.nodc.noaa.gov/ghrsst/GDS2/L2P/MODIS_A/JPL/v2019.0',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'The HTTP location '
#                                                           'for the collection.',
#                                            'GetData': { 'Format': 'Not '
#                                                                   'provided',
#                                                         'MimeType': 'text/html',
#                                                         'Size': 0.0,
#                                                         'Unit': 'KB'},
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/ghrsst/data/GDS2/L2P/MODIS_A/JPL/v2019.0',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://oceancolor.gsfc.nasa.gov/atbd/sst4/',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': '(Search Granule)',
#                                            'GetData': { 'Format': 'Not '
#                                                                   'provided',
#                                                         'MimeType': 'application/xml',
#                                                         'Size': 0.0,
#                                                         'Unit': 'KB'},
#                                            'Subtype': 'DIRECT DOWNLOAD',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHMDA-2PJ19',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'Thumbnail image for '
#                                                           'Website',
#                                            'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': '/data/export/web/thumbnails',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://oceancolor.gsfc.nasa.gov/reprocessing/r2019/sst/',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Type': 'PROJECT HOME PAGE',
#                                            'URL': 'http://www.ghrsst.org',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://podaac.jpl.nasa.gov/forum/viewforum.php?f=18&sid=e2d67e5a01815fc6e39fcd2087ed8bc8',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'http://ghrsst.jpl.nasa.gov',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': 'Documentation on '
#                                                           'the GDS version 2 '
#                                                           'format '
#                                                           'specification',
#                                            'Subtype': "USER'S GUIDE",
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/drive/files/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': 'Select (Sea Surface '
#                                                           'Temperature - '
#                                                           'Infrared)',
#                                            'Type': 'GOTO WEB TOOL',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/soto/',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://oceancolor.gsfc.nasa.gov/atbd/sst/flag/',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://modis.gsfc.nasa.gov/data/atbd/atbd_mod25.pdf',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': 'HIgh-level Tool for '
#                                                           'Interactive Data '
#                                                           'Extraction',
#                                            'Type': 'GOTO WEB TOOL',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/hitide/',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://oceancolor.gsfc.nasa.gov/atbd/sst/',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Type': 'DOWNLOAD SOFTWARE',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/ghrsst/sw/generic_nc_readers/',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'Access the data set '
#                                                           'landing page for '
#                                                           'the collection.',
#                                            'Type': 'DATA SET LANDING PAGE',
#                                            'URL': 'https://doi.org/10.5067/GHMDA-2PJ19',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Description': 'The OPeNDAP base '
#                                                           'directory location '
#                                                           'for the collection.',
#                                            'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/MODIS_A/JPL/v2019.0/',
#                                            'URLContentType': 'PublicationURL'}],
#                         'ScienceKeywords': [ { 'Category': 'EARTH SCIENCE',
#                                                'DetailedVariable': 'SEA '
#                                                                    'SURFACE '
#                                                                    'SKIN '
#                                                                    'TEMPERATURE',
#                                                'Term': 'OCEAN TEMPERATURE',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'SEA SURFACE '
#                                                                  'TEMPERATURE'}],
#                         'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                         'SpatialExtent': { 'GranuleSpatialRepresentation': 'CARTESIAN',
#                                            'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': 90.0,
#                                                                                                                 'SouthBoundingCoordinate': -90.0,
#                                                                                                                 'WestBoundingCoordinate': -180.0}],
#                                                                                       'CoordinateSystem': 'CARTESIAN'},
#                                                                         'ResolutionAndCoordinateSystem': { 'GeodeticModel': { 'DenominatorOfFlatteningRatio': 298.2572236,
#                                                                                                                               'EllipsoidName': 'WGS '
#                                                                                                                                                '84',
#                                                                                                                               'HorizontalDatumName': 'World '
#                                                                                                                                                      'Geodetic '
#                                                                                                                                                      'System '
#                                                                                                                                                      '1984',
#                                                                                                                               'SemiMajorAxis': 6378137}}},
#                                            'SpatialCoverageType': 'HORIZONTAL'},
#                         'TemporalExtents': [ { 'EndsAtPresentFlag': False,
#                                                'RangeDateTimes': [ { 'BeginningDateTime': '2002-07-04T00:00:00.000Z'}]}],
#                         'Version': '2019.0'}},
#              { 'meta': { 'associations': { 'services': ['S1234899453-POCLOUD'],
#                                            'variables': [ 'V1234936833-POCLOUD',
#                                                           'V1234936829-POCLOUD',
#                                                           'V1234936819-POCLOUD',
#                                                           'V1234936817-POCLOUD',
#                                                           'V1234936825-POCLOUD',
#                                                           'V1234936821-POCLOUD',
#                                                           'V1234936831-POCLOUD',
#                                                           'V1234936835-POCLOUD',
#                                                           'V1234936823-POCLOUD',
#                                                           'V1234936827-POCLOUD',
#                                                           'V1234936837-POCLOUD']},
#                          'concept-id': 'C1234724471-POCLOUD',
#                          'concept-type': 'collection',
#                          'deleted': False,
#                          'format': 'application/echo10+xml',
#                          'granule-count': 0,
#                          'has-formats': True,
#                          'has-spatial-subsetting': True,
#                          'has-temporal-subsetting': False,
#                          'has-transforms': False,
#                          'has-variables': True,
#                          'native-id': 'MODIS_T-JPL-L2P-v2019.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-05-14T23:48:57Z',
#                          'revision-id': 1,
#                          'user-id': 'nchung'},
#                'umm': { 'Abstract': 'NASA produces skin sea surface '
#                                     'temperature (SST) products from the '
#                                     'Infrared (IR) channels of the '
#                                     'Moderate-resolution Imaging '
#                                     'Spectroradiometer (MODIS) onboard the '
#                                     'Terra satellite. Terra was launched by '
#                                     'NASA on December 18, 1999, into a sun '
#                                     'synchronous, polar orbit with a daylight '
#                                     'descending node at 10:30 am, to study the '
#                                     'global dynamics of the Earth atmosphere, '
#                                     'land and oceans. The MODIS captures data '
#                                     'in 36 spectral bands at a variety of '
#                                     'spatial resolutions.  Two SST products '
#                                     'can be present in these files. The first '
#                                     'is a skin SST produced for both day and '
#                                     'night observations, derived from the long '
#                                     'wave IR 11 and 12 micron wavelength '
#                                     'channels, using a modified nonlinear SST '
#                                     'algorithm intended to provide continuity '
#                                     'with SST derived from heritage and '
#                                     'current NASA sensors. At night, a second '
#                                     'SST product is produced using the '
#                                     'mid-infrared 3.95 and 4.05 micron '
#                                     'channels which are unique to MODIS; the '
#                                     'SST derived from these measurements is '
#                                     'identified as SST4. The SST4 product has '
#                                     'lower uncertainty, but due to sun glint '
#                                     'can only be produced at night. MODIS L2P '
#                                     'SST data have a 1 km spatial resolution '
#                                     'at nadir and are stored in 288 five '
#                                     'minute granules per day. Full global '
#                                     'coverage is obtained every two days, with '
#                                     'coverage poleward of 32.3 degree being '
#                                     'complete each day. The production of '
#                                     'MODIS L2P SST files is part of the Group '
#                                     'for High Resolution Sea Surface '
#                                     'Temperature (GHRSST) project, and is a '
#                                     'joint collaboration between the NASA Jet '
#                                     'Propulsion Laboratory (JPL), the NASA '
#                                     'Ocean Biology Processing Group (OBPG), '
#                                     'and the Rosenstiel School of Marine and '
#                                     'Atmospheric Science (RSMAS). Researchers '
#                                     'at RSMAS are responsible for SST '
#                                     'algorithm development, error statistics '
#                                     'and quality flagging, while the OBPG, as '
#                                     'the NASA ground data system, is '
#                                     'responsible for the production of daily '
#                                     'MODIS ocean products. JPL acquires MODIS '
#                                     'ocean granules from the OBPG and '
#                                     'reformats them to the GHRSST L2P netCDF '
#                                     'specification with complete metadata and '
#                                     'ancillary variables, and distributes the '
#                                     'data as the official Physical '
#                                     'Oceanography Data Archive (PO.DAAC) for '
#                                     'SST.  The R2019.0 supersedes the previous '
#                                     'R2014.0 datasets which can be found at  '
#                                     'https://doi.org/10.5067/GHMDT-2PJ02',
#                         'ArchiveAndDistributionInformation': { 'FileDistributionInformation': [ { 'Format': 'NETCDF',
#                                                                                                   'FormatType': 'Native'}]},
#                         'CollectionCitations': [ { 'OtherCitationDetails': 'JPL/OBPG/RSMAS, '
#                                                                            'Jet '
#                                                                            'Propulsion '
#                                                                            'Laboratory, '
#                                                                            '2020-01-15, '
#                                                                            'GHRSST '
#                                                                            'Level '
#                                                                            '2P '
#                                                                            'Global '
#                                                                            'Sea '
#                                                                            'Surface '
#                                                                            'Skin '
#                                                                            'Temperature '
#                                                                            'from '
#                                                                            'the '
#                                                                            'Moderate '
#                                                                            'Resolution '
#                                                                            'Imaging '
#                                                                            'Spectroradiometer '
#                                                                            '(MODIS) '
#                                                                            'on '
#                                                                            'the '
#                                                                            'NASA '
#                                                                            'Terra '
#                                                                            'satellite '
#                                                                            '(GDS2), '
#                                                                            '10.5067/GHMDT-2PJ19, '
#                                                                            'Information '
#                                                                            'on '
#                                                                            'the '
#                                                                            'the '
#                                                                            'MODIS '
#                                                                            'SST '
#                                                                            'algorithm '
#                                                                            'can '
#                                                                            'be '
#                                                                            'found '
#                                                                            'in '
#                                                                            'the '
#                                                                            'following '
#                                                                            'documents: '
#                                                                            'http://modis.gsfc.nasa.gov/data/atbd/atbd_mod25.pdf '
#                                                                            'and '
#                                                                            'http://oceancolor.gsfc.nasa.gov/DOCS/modis_sst/'}],
#                         'CollectionProgress': 'NOT PROVIDED',
#                         'DOI': {'DOI': '10.5067/GHMDT-2PJ19'},
#                         'DataCenters': [ { 'Roles': ['PROCESSOR'],
#                                            'ShortName': 'Jet Propulsion '
#                                                         'Laboratory'},
#                                          { 'Roles': ['ARCHIVER'],
#                                            'ShortName': 'NASA/JPL/PODAAC'},
#                                          { 'ContactInformation': { 'ContactMechanisms': [ { 'Type': 'Primary',
#                                                                                             'Value': '818-393-6710'},
#                                                                                           { 'Type': 'Email',
#                                                                                             'Value': 'edward.m.armstrong@jpl.nasa.gov'}]},
#                                            'ContactPersons': [ { 'FirstName': 'Edward',
#                                                                  'LastName': 'Armstrong',
#                                                                  'MiddleName': 'none',
#                                                                  'Roles': [ 'Technical '
#                                                                             'Contact']}],
#                                            'LongName': 'Physical Oceanography '
#                                                        'Distributed Active '
#                                                        'Archive Center, Jet '
#                                                        'Propulsion Laboratory, '
#                                                        'NASA',
#                                            'Roles': ['ARCHIVER'],
#                                            'ShortName': 'Physical Oceanography '
#                                                         'Distributed Active '
#                                                         'Archive Center, Jet '
#                                                         'Propulsion '
#                                                         'Laboratory, N'},
#                                          { 'ContactInformation': { 'ContactMechanisms': [ { 'Type': 'Primary',
#                                                                                             'Value': '305-421-4615'},
#                                                                                           { 'Type': 'Email',
#                                                                                             'Value': 'KKilpatrick@rsmas.miami.edu'}]},
#                                            'ContactPersons': [ { 'FirstName': 'Kay',
#                                                                  'LastName': 'Kilpatrick',
#                                                                  'MiddleName': 'none',
#                                                                  'Roles': [ 'Investigator']}],
#                                            'Roles': ['ARCHIVER'],
#                                            'ShortName': 'Rosenstiel School of '
#                                                         'Marine and '
#                                                         'Atmospheric Science'}],
#                         'DataDates': [ { 'Date': '2019-12-31T19:19:57.627Z',
#                                          'Type': 'CREATE'},
#                                        { 'Date': '2019-12-31T19:19:57.627Z',
#                                          'Type': 'UPDATE'}],
#                         'EntryTitle': 'GHRSST Level 2P Global Sea Surface Skin '
#                                       'Temperature from the Moderate '
#                                       'Resolution Imaging Spectroradiometer '
#                                       '(MODIS) on the NASA Terra satellite '
#                                       '(GDS2)',
#                         'LocationKeywords': [ { 'Category': 'GEOGRAPHIC REGION',
#                                                 'Type': 'GLOBAL'}],
#                         'MetadataDates': [ { 'Date': '2020-02-12T15:08:00.364Z',
#                                              'Type': 'UPDATE'}],
#                         'Platforms': [ { 'Characteristics': [ { 'DataType': 'FLOAT',
#                                                                 'Description': 'Nominal '
#                                                                                'period '
#                                                                                'of '
#                                                                                'a '
#                                                                                'spacecraft?s '
#                                                                                'single '
#                                                                                'revolution '
#                                                                                'on '
#                                                                                'an '
#                                                                                'orbital '
#                                                                                'plane.',
#                                                                 'Name': 'OrbitPeriod',
#                                                                 'Unit': 'Minutes',
#                                                                 'Value': '98.8'},
#                                                               { 'DataType': 'FLOAT',
#                                                                 'Description': 'Spacecraft '
#                                                                                'angular '
#                                                                                'distance '
#                                                                                'from '
#                                                                                'orbital '
#                                                                                'plane '
#                                                                                'relative '
#                                                                                'to '
#                                                                                'the '
#                                                                                'Equator.',
#                                                                 'Name': 'InclinationAngle',
#                                                                 'Unit': 'Degrees',
#                                                                 'Value': '98.2'}],
#                                          'Instruments': [ { 'Characteristics': [ { 'DataType': 'FLOAT',
#                                                                                    'Description': 'Spacecraft '
#                                                                                                   'angular '
#                                                                                                   'distance '
#                                                                                                   'from '
#                                                                                                   'orbital '
#                                                                                                   'plane '
#                                                                                                   'relative '
#                                                                                                   'to '
#                                                                                                   'the '
#                                                                                                   'Equator.',
#                                                                                    'Name': 'SwathWidth',
#                                                                                    'Unit': 'Meters',
#                                                                                    'Value': '2330.0'}],
#                                                             'LongName': 'Moderate-Resolution '
#                                                                         'Imaging '
#                                                                         'Spectroradiometer',
#                                                             'ShortName': 'MODIS'}],
#                                          'LongName': 'Earth Observing System, '
#                                                      'TERRA',
#                                          'ShortName': 'Terra',
#                                          'Type': 'SPACECRAFT'}],
#                         'ProcessingLevel': {'Id': '2'},
#                         'Projects': [{'ShortName': 'GHRSST'}],
#                         'RelatedUrls': [ { 'Description': 'The HTTP location '
#                                                           'for the collection.',
#                                            'GetData': { 'Format': 'Not '
#                                                                   'provided',
#                                                         'MimeType': 'text/html',
#                                                         'Size': 0.0,
#                                                         'Unit': 'KB'},
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/ghrsst/data/GDS2/L2P/MODIS_T/JPL/v2019.0',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'The HTTP location '
#                                                           'for the collection.',
#                                            'GetData': { 'Format': 'Not '
#                                                                   'provided',
#                                                         'MimeType': 'text/html',
#                                                         'Size': 0.0,
#                                                         'Unit': 'KB'},
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://data.nodc.noaa.gov/ghrsst/GDS2/L2P/MODIS_T/JPL/v2019.0',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://modis.gsfc.nasa.gov/data/atbd/atbd_mod25.pdf',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': 'Documentation on '
#                                                           'the GDS version 2 '
#                                                           'format '
#                                                           'specification',
#                                            'Subtype': "USER'S GUIDE",
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/drive/files/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://oceancolor.gsfc.nasa.gov/atbd/sst4/',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'http://ghrsst.jpl.nasa.gov',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': '(Search Granule)',
#                                            'GetData': { 'Format': 'Not '
#                                                                   'provided',
#                                                         'MimeType': 'application/xml',
#                                                         'Size': 0.0,
#                                                         'Unit': 'KB'},
#                                            'Subtype': 'DIRECT DOWNLOAD',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHMDT-2PJ19',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Type': 'DOWNLOAD SOFTWARE',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/ghrsst/sw/generic_nc_readers/',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://oceancolor.gsfc.nasa.gov/reprocessing/r2019/sst/',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://oceancolor.gsfc.nasa.gov/atbd/sst/flag/',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Description': 'HIgh-level Tool for '
#                                                           'Interactive Data '
#                                                           'Extraction',
#                                            'Type': 'GOTO WEB TOOL',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/hitide/',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'Select (Sea Surface '
#                                                           'Temperature - '
#                                                           'Infrared)',
#                                            'Type': 'GOTO WEB TOOL',
#                                            'URL': 'https://podaac-tools.jpl.nasa.gov/soto/',
#                                            'URLContentType': 'DistributionURL'},
#                                          { 'Description': 'Thumbnail image for '
#                                                           'Website',
#                                            'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': '/data/export/web/thumbnails',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://podaac.jpl.nasa.gov/forum/viewforum.php?f=18&sid=e2d67e5a01815fc6e39fcd2087ed8bc8',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://oceancolor.gsfc.nasa.gov/atbd/sst/',
#                                            'URLContentType': 'PublicationURL'},
#                                          { 'Type': 'PROJECT HOME PAGE',
#                                            'URL': 'http://www.ghrsst.org',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Description': 'Access the data set '
#                                                           'landing page for '
#                                                           'the collection.',
#                                            'Type': 'DATA SET LANDING PAGE',
#                                            'URL': 'https://doi.org/10.5067/GHMDT-2PJ19',
#                                            'URLContentType': 'CollectionURL'},
#                                          { 'Description': 'The OPeNDAP base '
#                                                           'directory location '
#                                                           'for the collection.',
#                                            'Subtype': 'GENERAL DOCUMENTATION',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/MODIS_T/JPL/v2019.0/',
#                                            'URLContentType': 'PublicationURL'}],
#                         'ScienceKeywords': [ { 'Category': 'EARTH SCIENCE',
#                                                'DetailedVariable': 'SEA '
#                                                                    'SURFACE '
#                                                                    'SKIN '
#                                                                    'TEMPERATURE',
#                                                'Term': 'OCEAN TEMPERATURE',
#                                                'Topic': 'OCEANS',
#                                                'VariableLevel1': 'SEA SURFACE '
#                                                                  'TEMPERATURE'}],
#                         'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                         'SpatialExtent': { 'GranuleSpatialRepresentation': 'CARTESIAN',
#                                            'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': 90.0,
#                                                                                                                 'SouthBoundingCoordinate': -90.0,
#                                                                                                                 'WestBoundingCoordinate': -180.0}],
#                                                                                       'CoordinateSystem': 'CARTESIAN'},
#                                                                         'ResolutionAndCoordinateSystem': { 'GeodeticModel': { 'DenominatorOfFlatteningRatio': 298.2572236,
#                                                                                                                               'EllipsoidName': 'WGS '
#                                                                                                                                                '84',
#                                                                                                                               'HorizontalDatumName': 'World '
#                                                                                                                                                      'Geodetic '
#                                                                                                                                                      'System '
#                                                                                                                                                      '1984',
#                                                                                                                               'SemiMajorAxis': 6378137}}},
#                                            'SpatialCoverageType': 'HORIZONTAL'},
#                         'TemporalExtents': [ { 'EndsAtPresentFlag': False,
#                                                'RangeDateTimes': [ { 'BeginningDateTime': '2002-07-04T00:00:00.000Z'}]}],
#                         'Version': '2019.0'}}],
#   'took': 238}

# %% [markdown]
# ## CMO: should add how to search by collection name, e.g. MODIS, Jason-1
# so user can identify the shortname, needed in other notebooks

# %% [markdown]
# Ok, that got us down to 2 collections. Let's use python to get some information we're interested in.

# %%
for i in JSON_object["items"]:
  print(i['meta']['concept-id'] + " " + i['meta']['native-id'].replace('+',' '))
  #print("\t"+i['meta']['native-id'].replace('+',' '))
  print("\tBeginning Data Time: "+str(i['umm']['TemporalExtents'][0]['RangeDateTimes'][0]['BeginningDateTime']))
    
  # Bounding Box Info:
  br_array = i['umm']['SpatialExtent']['HorizontalSpatialDomain']['Geometry']['BoundingRectangles']
  for br in br_array:
    print("\tBounding Rectangle: West: {}, North: {}, East: {}, South: {}".format(br['WestBoundingCoordinate'], br['NorthBoundingCoordinate'], br['EastBoundingCoordinate'], br['SouthBoundingCoordinate']))
# Out:
# C1234724470-POCLOUD MODIS_A-JPL-L2P-v2019.0
# 	Beginning Data Time: 2002-07-04T00:00:00.000Z
# 	Bounding Rectangle: West: -180.0, North: 90.0, East: 180.0, South: -90.0
# C1234724471-POCLOUD MODIS_T-JPL-L2P-v2019.0
# 	Beginning Data Time: 2002-07-04T00:00:00.000Z
# 	Bounding Rectangle: West: -180.0, North: 90.0, East: 180.0, South: -90.0

# %% [markdown]
# We now have the following information:
# - start times,
# - CMR Concept-ID (the unique collection identifier),
# - title, and
# - bounding rectangles for spatial coverage.
#
# This is a lot of information we can use to decide on a dataset, and we can keep adding more information.
#
# For now, lets choose "C1234724470": POCLOUD MODIS_A-JPL-L2P-v2019.0, MODIS L2 SST data.

# %% [markdown]
# ## Granule Search
#
# Using this collection, and more specifically, its concept-ID, we can now search for data we're interested in.

# %%
with request.urlopen(cmr_url+"granules.umm_json?concept-id=C1234724470-POCLOUD") as response:
    data = response.read()
    encoding = response.info().get_content_charset('utf-8')
    JSON_object = json.loads(data.decode(encoding))
    pp = pprint.PrettyPrinter(indent=2)
    pp.pprint(JSON_object)
# Out:
# { 'hits': 26933,
#   'items': [ { 'meta': { 'concept-id': 'G1234900141-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927000500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:12:04Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 20.616602897644043,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:17:29.000Z'},
#                         'GranuleUR': '20190927000500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:11:46.897Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:11:46.897Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927000500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927000500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -101.679,
#                                                                                                                 'NorthBoundingCoordinate': -53.648,
#                                                                                                                 'SouthBoundingCoordinate': -77.167,
#                                                                                                                 'WestBoundingCoordinate': -170.5}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:05:00.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:10:00.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900130-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927001001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:11:54Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 20.53339385986328,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:17:33.000Z'},
#                         'GranuleUR': '20190927001001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:11:37.200Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:11:37.201Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927001001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927001001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -127.663,
#                                                                                                                 'NorthBoundingCoordinate': -37.433,
#                                                                                                                 'SouthBoundingCoordinate': -59.243,
#                                                                                                                 'WestBoundingCoordinate': -166.974}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:10:01.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:15:00.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234899729-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927001501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-08T23:52:10Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 20.605507850646973,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:17:37.000Z'},
#                         'GranuleUR': '20190927001501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-08T23:51:26.396Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-08T23:51:26.396Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927001501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927001501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -139.663,
#                                                                                                                 'NorthBoundingCoordinate': -20.226,
#                                                                                                                 'SouthBoundingCoordinate': -41.414,
#                                                                                                                 'WestBoundingCoordinate': -169.158}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:15:01.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:20:00.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234899734-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927002001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-08T23:52:24Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 20.817957878112793,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:17:42.000Z'},
#                         'GranuleUR': '20190927002001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-08T23:52:04.339Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-08T23:52:04.341Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927002001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927002001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -146.654,
#                                                                                                                 'NorthBoundingCoordinate': -2.57,
#                                                                                                                 'SouthBoundingCoordinate': -23.521,
#                                                                                                                 'WestBoundingCoordinate': -172.197}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:20:01.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:25:00.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900118-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927002501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:10:57Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 21.32480525970459,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:17:46.000Z'},
#                         'GranuleUR': '20190927002501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:10:39.970Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:10:39.971Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927002501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927002501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -151.423,
#                                                                                                                 'NorthBoundingCoordinate': 15.296,
#                                                                                                                 'SouthBoundingCoordinate': -5.619,
#                                                                                                                 'WestBoundingCoordinate': -176.232}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:25:01.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:29:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900137-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927003001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:11:58Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 20.73535919189453,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:17:51.000Z'},
#                         'GranuleUR': '20190927003001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:11:41.028Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:11:41.029Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927003001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927003001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': 33.24,
#                                                                                                                 'SouthBoundingCoordinate': 12.183,
#                                                                                                                 'WestBoundingCoordinate': 178.094},
#                                                                                                               { 'EastBoundingCoordinate': -154.987,
#                                                                                                                 'NorthBoundingCoordinate': 33.24,
#                                                                                                                 'SouthBoundingCoordinate': 12.183,
#                                                                                                                 'WestBoundingCoordinate': -180.0}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:30:01.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:34:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900131-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927003501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:11:54Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 20.393349647521973,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:17:55.000Z'},
#                         'GranuleUR': '20190927003501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:11:37.310Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:11:37.310Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927003501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927003501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': 51.166,
#                                                                                                                 'SouthBoundingCoordinate': 29.707,
#                                                                                                                 'WestBoundingCoordinate': 169.065},
#                                                                                                               { 'EastBoundingCoordinate': -157.701,
#                                                                                                                 'NorthBoundingCoordinate': 51.166,
#                                                                                                                 'SouthBoundingCoordinate': 29.707,
#                                                                                                                 'WestBoundingCoordinate': -180.0}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:35:01.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:39:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900128-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927004001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:11:54Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 19.725990295410156,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:18:00.000Z'},
#                         'GranuleUR': '20190927004001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:11:37.218Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:11:37.218Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927004001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927004001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': 69.082,
#                                                                                                                 'SouthBoundingCoordinate': 46.601,
#                                                                                                                 'WestBoundingCoordinate': 151.357},
#                                                                                                               { 'EastBoundingCoordinate': -159.171,
#                                                                                                                 'NorthBoundingCoordinate': 69.082,
#                                                                                                                 'SouthBoundingCoordinate': 46.601,
#                                                                                                                 'WestBoundingCoordinate': -180.0}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:40:01.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:44:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900120-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927004500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:10:59Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 19.718886375427246,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:18:04.000Z'},
#                         'GranuleUR': '20190927004500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:10:40.815Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:10:40.815Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927004500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927004500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': 87.01,
#                                                                                                                 'SouthBoundingCoordinate': 61.824,
#                                                                                                                 'WestBoundingCoordinate': 110.451},
#                                                                                                               { 'EastBoundingCoordinate': -129.162,
#                                                                                                                 'NorthBoundingCoordinate': 87.01,
#                                                                                                                 'SouthBoundingCoordinate': 61.824,
#                                                                                                                 'WestBoundingCoordinate': -180.0}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T00:45:00.000Z',
#                                                                'EndingDateTime': '2019-09-27T00:49:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900134-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927014500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:11:56Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 20.68394374847412,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:18:08.000Z'},
#                         'GranuleUR': '20190927014500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:11:37.815Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:11:37.815Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927014500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927014500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 180.0,
#                                                                                                                 'NorthBoundingCoordinate': -50.167,
#                                                                                                                 'SouthBoundingCoordinate': -73.182,
#                                                                                                                 'WestBoundingCoordinate': 167.035},
#                                                                                                               { 'EastBoundingCoordinate': -134.271,
#                                                                                                                 'NorthBoundingCoordinate': -50.167,
#                                                                                                                 'SouthBoundingCoordinate': -73.182,
#                                                                                                                 'WestBoundingCoordinate': -180.0}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T01:45:00.000Z',
#                                                                'EndingDateTime': '2019-09-27T01:50:00.000Z'}}}}],
#   'took': 31}

# %% [markdown]
# Alright, 11489 hits (at time of this writing). Let's once again use some parsing magic to get some information on these data granules.

# %%
for i in JSON_object["items"]:
  print(i['meta']['concept-id'] + " " + i['meta']['native-id'].replace('+',' '))

  dist_info = i['umm']['DataGranule']['ArchiveAndDistributionInformation'][0]
  print("\tGranule Size: "+"{:.3f}".format(dist_info['Size']) + " " + str(dist_info['SizeUnit']))
  print("\tBeginning Data Time: "+str(i['umm']['TemporalExtent']['RangeDateTime']['BeginningDateTime']))
    
# Bounding Box Info - or spatial extent of the data .... in the granule???:
  br_array = i['umm']['SpatialExtent']['HorizontalSpatialDomain']['Geometry']['BoundingRectangles']
  for br in br_array:
    print("\tBounding Rectangle: West: {}, North: {}, East: {}, South: {}".format(br['WestBoundingCoordinate'], br['NorthBoundingCoordinate'], br['EastBoundingCoordinate'], br['SouthBoundingCoordinate']))

  related_urls = i['umm']['RelatedUrls']
  for url in related_urls:
        print("\t{} ({})".format(url["URL"], url['Description']))
# Out:
# G1234900141-POCLOUD 20190927000500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 20.617 MB
# 	Beginning Data Time: 2019-09-27T00:05:00.000Z
# 	Bounding Rectangle: West: -170.5, North: -53.648, East: -101.679, South: -77.167
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927000500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927000500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234900130-POCLOUD 20190927001001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 20.533 MB
# 	Beginning Data Time: 2019-09-27T00:10:01.000Z
# 	Bounding Rectangle: West: -166.974, North: -37.433, East: -127.663, South: -59.243
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927001001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927001001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234899729-POCLOUD 20190927001501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 20.606 MB
# 	Beginning Data Time: 2019-09-27T00:15:01.000Z
# 	Bounding Rectangle: West: -169.158, North: -20.226, East: -139.663, South: -41.414
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927001501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927001501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234899734-POCLOUD 20190927002001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 20.818 MB
# 	Beginning Data Time: 2019-09-27T00:20:01.000Z
# 	Bounding Rectangle: West: -172.197, North: -2.57, East: -146.654, South: -23.521
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927002001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927002001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234900118-POCLOUD 20190927002501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 21.325 MB
# 	Beginning Data Time: 2019-09-27T00:25:01.000Z
# 	Bounding Rectangle: West: -176.232, North: 15.296, East: -151.423, South: -5.619
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927002501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927002501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234900137-POCLOUD 20190927003001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 20.735 MB
# 	Beginning Data Time: 2019-09-27T00:30:01.000Z
# 	Bounding Rectangle: West: 178.094, North: 33.24, East: 180.0, South: 12.183
# 	Bounding Rectangle: West: -180.0, North: 33.24, East: -154.987, South: 12.183
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927003001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927003001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234900131-POCLOUD 20190927003501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 20.393 MB
# 	Beginning Data Time: 2019-09-27T00:35:01.000Z
# 	Bounding Rectangle: West: 169.065, North: 51.166, East: 180.0, South: 29.707
# 	Bounding Rectangle: West: -180.0, North: 51.166, East: -157.701, South: 29.707
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927003501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927003501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234900128-POCLOUD 20190927004001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 19.726 MB
# 	Beginning Data Time: 2019-09-27T00:40:01.000Z
# 	Bounding Rectangle: West: 151.357, North: 69.082, East: 180.0, South: 46.601
# 	Bounding Rectangle: West: -180.0, North: 69.082, East: -159.171, South: 46.601
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927004001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927004001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234900120-POCLOUD 20190927004500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 19.719 MB
# 	Beginning Data Time: 2019-09-27T00:45:00.000Z
# 	Bounding Rectangle: West: 110.451, North: 87.01, East: 180.0, South: 61.824
# 	Bounding Rectangle: West: -180.0, North: 87.01, East: -129.162, South: 61.824
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927004500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927004500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)
# G1234900134-POCLOUD 20190927014500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0
# 	Granule Size: 20.684 MB
# 	Beginning Data Time: 2019-09-27T01:45:00.000Z
# 	Bounding Rectangle: West: 167.035, North: -50.167, East: 180.0, South: -73.182
# 	Bounding Rectangle: West: -180.0, North: -50.167, East: -134.271, South: -73.182
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927014500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc (The base directory location for the granule.)
# 	https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927014500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json (File to download)
# 	https://archive.podaac.uat.earthdata.nasa.gov/s3credentials (api endpoint to retrieve temporary credentials valid for same-region direct s3 access)

# %% [markdown]
# ### Find granules IDs for data in given collection, for an geospatial region of interest within a bounding box

# %%
#cmo: trying to only return granules within this collection that area within a bbox of interest
with request.urlopen(cmr_url+"granules.umm_json?concept-id=C1234724470-POCLOUD&bounding_box=-10,-5,10,5") as response:
    data = response.read()
    encoding = response.info().get_content_charset('utf-8')
    JSON_object = json.loads(data.decode(encoding))
    pp = pprint.PrettyPrinter(indent=2)
    pp.pprint(JSON_object)
# Out:
# { 'hits': 512,
#   'items': [ { 'meta': { 'concept-id': 'G1234899651-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927120001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-08T23:54:03Z',
#                          'revision-id': 2},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 17.134727478027344,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:45:01.000Z'},
#                         'GranuleUR': '20190927120001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-08T23:53:44.720Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-08T23:53:44.720Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927120001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927120001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 33.407,
#                                                                                                                 'NorthBoundingCoordinate': 25.396,
#                                                                                                                 'SouthBoundingCoordinate': 4.424,
#                                                                                                                 'WestBoundingCoordinate': 7.792}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T12:00:01.000Z',
#                                                                'EndingDateTime': '2019-09-27T12:05:00.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234899792-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927133500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-08T23:54:03Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 21.84565544128418,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:45:35.000Z'},
#                         'GranuleUR': '20190927133500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-08T23:53:45.667Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-08T23:53:45.667Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927133500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927133500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 11.726,
#                                                                                                                 'NorthBoundingCoordinate': 11.472,
#                                                                                                                 'SouthBoundingCoordinate': -9.525,
#                                                                                                                 'WestBoundingCoordinate': -13.038}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T13:35:00.000Z',
#                                                                'EndingDateTime': '2019-09-27T13:40:00.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900177-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190927151000-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:14:00Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 21.56572437286377,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:46:12.000Z'},
#                         'GranuleUR': '20190927151000-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:13:39.912Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:13:39.912Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190927151000-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190927151000-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -9.166,
#                                                                                                                 'NorthBoundingCoordinate': -2.479,
#                                                                                                                 'SouthBoundingCoordinate': -23.428,
#                                                                                                                 'WestBoundingCoordinate': -34.708}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-27T15:10:00.000Z',
#                                                                'EndingDateTime': '2019-09-27T15:14:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900115-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190928123501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:10:55Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 18.34277057647705,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:13:36.000Z'},
#                         'GranuleUR': '20190928123501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:10:38.376Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:10:38.376Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190928123501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190928123501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 30.01,
#                                                                                                                 'NorthBoundingCoordinate': -4.205,
#                                                                                                                 'SouthBoundingCoordinate': -25.168,
#                                                                                                                 'WestBoundingCoordinate': 4.25}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-28T12:35:01.000Z',
#                                                                'EndingDateTime': '2019-09-28T12:39:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234899727-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190928124001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-08T23:52:09Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 18.700249671936035,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:13:40.000Z'},
#                         'GranuleUR': '20190928124001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-08T23:51:20.421Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-08T23:51:20.422Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190928124001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190928124001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 25.092,
#                                                                                                                 'NorthBoundingCoordinate': 13.648,
#                                                                                                                 'SouthBoundingCoordinate': -7.264,
#                                                                                                                 'WestBoundingCoordinate': 0.325}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-28T12:40:01.000Z',
#                                                                'EndingDateTime': '2019-09-28T12:44:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900066-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190928141501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:07:58Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 21.825794219970703,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:14:14.000Z'},
#                         'GranuleUR': '20190928141501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:07:42.023Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:07:42.024Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190928141501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190928141501-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 4.041,
#                                                                                                                 'NorthBoundingCoordinate': -0.227,
#                                                                                                                 'SouthBoundingCoordinate': -21.164,
#                                                                                                                 'WestBoundingCoordinate': -21.253}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-28T14:15:01.000Z',
#                                                                'EndingDateTime': '2019-09-28T14:19:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234900054-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190928142001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-09T00:07:53Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 20.767815589904785,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T06:14:18.000Z'},
#                         'GranuleUR': '20190928142001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-09T00:07:36.446Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-09T00:07:36.447Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190928142001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190928142001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -0.533,
#                                                                                                                 'NorthBoundingCoordinate': 17.655,
#                                                                                                                 'SouthBoundingCoordinate': -3.269,
#                                                                                                                 'WestBoundingCoordinate': -25.452}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-28T14:20:01.000Z',
#                                                                'EndingDateTime': '2019-09-28T14:24:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234899833-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190929132001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-08T23:56:00Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 21.931913375854492,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T05:42:37.000Z'},
#                         'GranuleUR': '20190929132001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-08T23:55:42.078Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-08T23:55:42.078Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190929132001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190929132001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 17.305,
#                                                                                                                 'NorthBoundingCoordinate': 1.941,
#                                                                                                                 'SouthBoundingCoordinate': -18.985,
#                                                                                                                 'WestBoundingCoordinate': -7.794}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-29T13:20:01.000Z',
#                                                                'EndingDateTime': '2019-09-29T13:24:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234899857-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190929132500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-08T23:57:54Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 19.37773036956787,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T05:42:41.000Z'},
#                         'GranuleUR': '20190929132500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-08T23:57:37.900Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-08T23:57:37.901Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190929132500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190929132500-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': 12.902,
#                                                                                                                 'NorthBoundingCoordinate': 19.836,
#                                                                                                                 'SouthBoundingCoordinate': -1.097,
#                                                                                                                 'WestBoundingCoordinate': -12.157}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-29T13:25:00.000Z',
#                                                                'EndingDateTime': '2019-09-29T13:29:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1234899867-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20190929150001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-06-08T23:57:57Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_A-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Name': 'Not '
#                                                                                           'provided',
#                                                                                   'Size': 22.02885913848877,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2019-12-13T05:43:09.000Z'},
#                         'GranuleUR': '20190929150001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-06-08T23:57:41.646Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-06-08T23:57:41.646Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'The base directory '
#                                                           'location for the '
#                                                           'granule.',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-protected/20190929150001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'File to download',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/podaac-uat-cumulus-public/20190929150001-JPL-L2P_GHRSST-SSTskin-MODIS_A-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.uat.earthdata.nasa.gov/s3credentials'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -8.522,
#                                                                                                                 'NorthBoundingCoordinate': 5.932,
#                                                                                                                 'SouthBoundingCoordinate': -14.982,
#                                                                                                                 'WestBoundingCoordinate': -33.377}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2019-09-29T15:00:01.000Z',
#                                                                'EndingDateTime': '2019-09-29T15:04:59.000Z'}}}}],
#   'took': 54}

# %%
for i in JSON_object["items"]:
#  print(i['meta']['concept-id'] + " " + i['meta']['native-id'].replace('+',' '))
    print(i['meta']['concept-id'])
# Out:
# G1234899651-POCLOUD
# G1234899792-POCLOUD
# G1234900177-POCLOUD
# G1234900115-POCLOUD
# G1234899727-POCLOUD
# G1234900066-POCLOUD
# G1234900054-POCLOUD
# G1234899833-POCLOUD
# G1234899857-POCLOUD
# G1234899867-POCLOUD

# %%
for i in JSON_object["items"]:
#Bounding Box Info - or spatial extent of the data .... in the granule???:
  br_array = i['umm']['SpatialExtent']['HorizontalSpatialDomain']['Geometry']['BoundingRectangles']
  for br in br_array:
    print("\tBounding Rectangle: West: {}, North: {}, East: {}, South: {}".format(br['WestBoundingCoordinate'], br['NorthBoundingCoordinate'], br['EastBoundingCoordinate'], br['SouthBoundingCoordinate']))
# Out:
# 	Bounding Rectangle: West: 7.792, North: 25.396, East: 33.407, South: 4.424
# 	Bounding Rectangle: West: -13.038, North: 11.472, East: 11.726, South: -9.525
# 	Bounding Rectangle: West: -34.708, North: -2.479, East: -9.166, South: -23.428
# 	Bounding Rectangle: West: 4.25, North: -4.205, East: 30.01, South: -25.168
# 	Bounding Rectangle: West: 0.325, North: 13.648, East: 25.092, South: -7.264
# 	Bounding Rectangle: West: -21.253, North: -0.227, East: 4.041, South: -21.164
# 	Bounding Rectangle: West: -25.452, North: 17.655, East: -0.533, South: -3.269
# 	Bounding Rectangle: West: -7.794, North: 1.941, East: 17.305, South: -18.985
# 	Bounding Rectangle: West: -12.157, North: 19.836, East: 12.902, South: -1.097
# 	Bounding Rectangle: West: -33.377, North: 5.932, East: -8.522, South: -14.982

# %% [markdown]
# Using the above information, we can find the size and location (both whole file and OPeNDAP) URLs.
# To further explore CRM and search for data, check out the CMR API guide https://cmr.earthdata.nasa.gov/search/site/docs/search/api.html#g-spatial
