# %% [markdown]
# # This Notebook is no longer up to date, a newer version exists [here](https://github.com/podaac/tutorials/blob/master/notebooks/PODAAC_CMR_Shapefile_Search_MODIS_UAT.ipynb)
# ## Shapefile Search in the Common Metadata Repository (CMR)
#
# CMR allows the upload of ESRI Shapefiles via command line for granule and collection level search. To use this functionality from the command line, we can use curl or python to do our search. This example will run through the curl command line program and a python request for doing shapefile search.
#
# Prerequisites:
#
# * a valid ESRI Shapefile
# * (optional) Collection identifier (concept-id) for granule level search
#
# We will use a shapefile located in the github/podaac source repository for this search: https://github.com/podaac/tutorials/blob/master/notebooks/resources/gulf_shapefile.zip
#
# For more information on collections, granules, and concept-ids, please refer to the following tutorial:
#
# https://github.com/podaac/tutorials/blob/master/notebooks/podaac_cmr_tutorial.ipynb
#
# For our tutorial, we will be using a **TEST** collection available at the cmr uat environment. This is an environment, open to the public, where new functionality is released and users can submit feedback on it before it makes its way to the operational system.
#
# This collection is an L2 collection titled AMSR2-REMSS-L2P-v8a, from the Advanced Microwave Scanning Radiometer 2. It has the concept id:
#
# **C1225996408-POCUMULUS**

# %% [markdown]
# ## Python tutorial shapefile search
#
# The following snippet will use the 'requests' library along with the shapefile available at github to perform a shapefile search on the CMR. It will return values that overlap or intersect the shapefile provided.

# %%
import requests
import json
import pprint

# the URL of the CMR searvice
url = 'https://cmr.uat.earthdata.nasa.gov/search/granules.json'

#The shapefile we want to use in our search
shp_file = open('resources/gulf_shapefile.zip', 'rb')

#need to declare the file and the type we are uploading
files = {'shapefile':('gulf_shapefile.zip',shp_file, 'application/shapefile+zip')}

#used to define parameters such as the concept-id and things like temporal searches
parameters = {'echo_collection_id':'C1225996408-POCUMULUS'}

response = requests.post(url, files=files, params=parameters)
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(response.json())
# Out:
# { 'feed': { 'entry': [ { 'browse_flag': False,
#                          'collection_concept_id': 'C1225996408-POCUMULUS',
#                          'coordinate_system': 'CARTESIAN',
#                          'data_center': 'POCUMULUS',
#                          'dataset_id': 'PODAAC-GHAM2-2PR8A',
#                          'day_night_flag': 'UNSPECIFIED',
#                          'granule_size': '1.0242048E7',
#                          'id': 'G1226019017-POCUMULUS',
#                          'links': [ { 'href': 's3://podaac-dev-l2ss-samples/20180101055616-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29921-v02.0-fv01.0.nc',
#                                       'hreflang': 'en-US',
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'http://data.nodc.noaa.gov/cgi-bin/nph-dods/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://ftp.nodc.noaa.gov/pub/data.nodc/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/IDL/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://suzaku.eorc.jaxa.jp/GCOM_W/w_amsr2/whats_amsr2.html',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://ghrsst.jpl.nasa.gov',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'https://podaac.jpl.nasa.gov/SeaSurfaceTemperature',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://podaac-tools.jpl.nasa.gov/hitide/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/R/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHAM2-2PR8A',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/matlab/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://www.remss.com/missions/amsr/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/python/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'}],
#                          'online_access_flag': True,
#                          'original_format': 'UMM_JSON',
#                          'polygons': [ [ '-74.21 -163.74 -72.95 -180 -75.43 '
#                                          '-180 -74.21 -163.74'],
#                                        [ '-72.95 180 -69.22 161.56 -63.56 '
#                                          '148.24 -59.74 142.63 -54.76 137.29 '
#                                          '-43.19 129.21 -28.81 123 -9.39 '
#                                          '117.38 70.28 101.89 78.71 98.84 83.8 '
#                                          '94.5 85.75 90.5 87.14 84.43 88.59 '
#                                          '63.9 89.12 2.26 88.28 -48.29 87.12 '
#                                          '-61.14 85.38 -68.1 82.54 -72.63 '
#                                          '77.71 -75.93 63.62 -80.05 9.8 -89.82 '
#                                          '-15.54 -95.55 -35.84 -102.3 -50.51 '
#                                          '-110.4 -56.3 -115.37 -60.99 -120.88 '
#                                          '-64.95 -127.37 -68.22 -135.08 -70.76 '
#                                          '-143.97 -72.76 -155.11 -74.35 -180 '
#                                          '-89.345 -180 -88.32 -113.33 -86.69 '
#                                          '-101.61 -83.86 -95.95 -79.32 -92.73 '
#                                          '-70.2 -89.86 -10.6 -79.24 16.19 '
#                                          '-73.27 33.1 -67.88 46.23 -61.6 52.76 '
#                                          '-57.05 57.86 -52.26 62.64 -46.04 '
#                                          '66.5 -38.81 69.5 -30.55 71.71 -21.38 '
#                                          '74.26 1.26 73.75 29.71 72.1 42.61 '
#                                          '69.64 53.42 66.25 62.72 62.36 69.82 '
#                                          '57.32 76.19 51.2 81.62 37.2 89.55 '
#                                          '18.32 96.04 -10.4 102.56 -70.39 '
#                                          '113.28 -79.49 116.19 -83.94 119.43 '
#                                          '-86.33 123.83 -87.89 131.86 -86.97 '
#                                          '131.68 -85.71 133.93 -81.4 147.95 '
#                                          '-77.84 164.04 -75.43 180 -72.95 180'],
#                                        [ '-74.35 180 -74.81 162.65 -77.45 '
#                                          '142.63 -82.89 118.89 -85.78 110.18 '
#                                          '-87.46 107.84 -88.13 109.51 -88.85 '
#                                          '123.7 -89.345 180 -74.35 180']],
#                          'time_end': '2018-01-01T07:34:24.000Z',
#                          'time_start': '2018-01-01T05:56:16.000Z',
#                          'title': '20180101055616-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29921-v02.0-fv01.0.nc'},
#                        { 'browse_flag': False,
#                          'collection_concept_id': 'C1225996408-POCUMULUS',
#                          'coordinate_system': 'CARTESIAN',
#                          'data_center': 'POCUMULUS',
#                          'dataset_id': 'PODAAC-GHAM2-2PR8A',
#                          'day_night_flag': 'UNSPECIFIED',
#                          'granule_size': '1.0242048E7',
#                          'id': 'G1226019025-POCUMULUS',
#                          'links': [ { 'href': 's3://podaac-dev-l2ss-samples/20180101055616-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_v08_r29921-v02.0-fv01.0.nc',
#                                       'hreflang': 'en-US',
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'http://data.nodc.noaa.gov/cgi-bin/nph-dods/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://ftp.nodc.noaa.gov/pub/data.nodc/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/IDL/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://suzaku.eorc.jaxa.jp/GCOM_W/w_amsr2/whats_amsr2.html',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://ghrsst.jpl.nasa.gov',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'https://podaac.jpl.nasa.gov/SeaSurfaceTemperature',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://podaac-tools.jpl.nasa.gov/hitide/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/R/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHAM2-2PR8A',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/matlab/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://www.remss.com/missions/amsr/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/python/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'}],
#                          'online_access_flag': True,
#                          'original_format': 'UMM_JSON',
#                          'polygons': [ [ '-74.21 -163.74 -72.95 -180 -75.43 '
#                                          '-180 -74.21 -163.74'],
#                                        [ '-72.95 180 -69.22 161.56 -63.56 '
#                                          '148.24 -59.74 142.63 -54.76 137.29 '
#                                          '-43.19 129.21 -28.81 123 -9.39 '
#                                          '117.38 70.28 101.89 78.71 98.84 83.8 '
#                                          '94.5 85.75 90.5 87.14 84.43 88.59 '
#                                          '63.9 89.12 2.26 88.28 -48.29 87.12 '
#                                          '-61.14 85.38 -68.1 82.54 -72.63 '
#                                          '77.71 -75.93 63.62 -80.05 9.8 -89.82 '
#                                          '-15.54 -95.55 -35.84 -102.3 -50.51 '
#                                          '-110.4 -56.3 -115.37 -60.99 -120.88 '
#                                          '-64.95 -127.37 -68.22 -135.08 -70.76 '
#                                          '-143.97 -72.76 -155.11 -74.35 -180 '
#                                          '-89.345 -180 -88.32 -113.33 -86.69 '
#                                          '-101.61 -83.86 -95.95 -79.32 -92.73 '
#                                          '-70.2 -89.86 -10.6 -79.24 16.19 '
#                                          '-73.27 33.1 -67.88 46.23 -61.6 52.76 '
#                                          '-57.05 57.86 -52.26 62.64 -46.04 '
#                                          '66.5 -38.81 69.5 -30.55 71.71 -21.38 '
#                                          '74.26 1.26 73.75 29.71 72.1 42.61 '
#                                          '69.64 53.42 66.25 62.72 62.36 69.82 '
#                                          '57.32 76.19 51.2 81.62 37.2 89.55 '
#                                          '18.32 96.04 -10.4 102.56 -70.39 '
#                                          '113.28 -79.49 116.19 -83.94 119.43 '
#                                          '-86.33 123.83 -87.89 131.86 -86.97 '
#                                          '131.68 -85.71 133.93 -81.4 147.95 '
#                                          '-77.84 164.04 -75.43 180 -72.95 180'],
#                                        [ '-74.35 180 -74.81 162.65 -77.45 '
#                                          '142.63 -82.89 118.89 -85.78 110.18 '
#                                          '-87.46 107.84 -88.13 109.51 -88.85 '
#                                          '123.7 -89.345 180 -74.35 180']],
#                          'time_end': '2018-01-01T07:34:24.000Z',
#                          'time_start': '2018-01-01T05:56:16.000Z',
#                          'title': '20180101055616-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_v08_r29921-v02.0-fv01.0.nc'},
#                        { 'browse_flag': False,
#                          'collection_concept_id': 'C1225996408-POCUMULUS',
#                          'coordinate_system': 'CARTESIAN',
#                          'data_center': 'POCUMULUS',
#                          'dataset_id': 'PODAAC-GHAM2-2PR8A',
#                          'day_night_flag': 'UNSPECIFIED',
#                          'granule_size': '1.0242048E7',
#                          'id': 'G1226019035-POCUMULUS',
#                          'links': [ { 'href': 's3://podaac-dev-l2ss-samples/20180101073424-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29922-v02.0-fv01.0.nc',
#                                       'hreflang': 'en-US',
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'http://data.nodc.noaa.gov/cgi-bin/nph-dods/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://ftp.nodc.noaa.gov/pub/data.nodc/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/IDL/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://suzaku.eorc.jaxa.jp/GCOM_W/w_amsr2/whats_amsr2.html',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://ghrsst.jpl.nasa.gov',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'https://podaac.jpl.nasa.gov/SeaSurfaceTemperature',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://podaac-tools.jpl.nasa.gov/hitide/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/R/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHAM2-2PR8A',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/matlab/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://www.remss.com/missions/amsr/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/python/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'}],
#                          'online_access_flag': True,
#                          'original_format': 'UMM_JSON',
#                          'polygons': [ [ '-74.22 171.81 -71.94 148.49 -69.79 '
#                                          '138.81 -66.95 130.42 -63.4 123.24 '
#                                          '-58.95 116.94 -54.1 111.97 -47.48 '
#                                          '107.01 -35.17 100.7 -19.62 95.36 '
#                                          '6.62 89.13 68.41 77.65 78.55 74.21 '
#                                          '83.9 69.64 85.85 65.49 87.07 60.19 '
#                                          '88.53 41.02 89.13 -17.61 88.42 '
#                                          '-70.04 87.45 -83.52 85.98 -91.12 '
#                                          '83.68 -96 80.02 -99.4 73.84 -102.16 '
#                                          '63.79 -104.74 12.85 -113.95 -9.83 '
#                                          '-118.81 -26.65 -123.58 -39.75 '
#                                          '-128.78 -46.92 -132.69 -53.16 -137.2 '
#                                          '-58.22 -142.13 -62.28 -147.47 -68.66 '
#                                          '-161.1 -72.78 -180 -89.27 -180 -88 '
#                                          '-134.22 -86.44 -125.51 -83.43 '
#                                          '-120.22 -78.08 -116.92 -67.8 -114.05 '
#                                          '-11.42 -104.12 16.09 -98.02 33.61 '
#                                          '-92.4 46.98 -85.86 53.32 -81.31 '
#                                          '58.48 -76.29 62.85 -70.43 66.69 '
#                                          '-63.09 69.49 -55.3 71.89 -45.14 '
#                                          '74.33 -21.85 73.7 5.56 71.97 18.61 '
#                                          '69.53 29.07 66.26 37.97 62.3 45.19 '
#                                          '56.93 51.87 50.63 57.32 36.78 65.01 '
#                                          '18.07 71.39 -9.84 77.73 -70.37 88.55 '
#                                          '-79.38 91.41 -84.28 95.11 -86.49 '
#                                          '99.58 -87.96 107.74 -87.46 107.2 '
#                                          '-86.78 107.65 -84.55 112.84 -79.08 '
#                                          '133.65 -75.67 153.77 -74.22 171.81'],
#                                        [ '-72.78 180 -74.16 163.81 -74.47 '
#                                          '142.46 -76.41 124.18 -82.12 96.85 '
#                                          '-85.44 86.21 -87.44 83.04 -88.28 '
#                                          '86.77 -88.98 104.28 -89.27 180 '
#                                          '-72.78 180']],
#                          'time_end': '2018-01-01T09:12:32.000Z',
#                          'time_start': '2018-01-01T07:34:24.000Z',
#                          'title': '20180101073424-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29922-v02.0-fv01.0.nc'},
#                        { 'browse_flag': False,
#                          'collection_concept_id': 'C1225996408-POCUMULUS',
#                          'coordinate_system': 'CARTESIAN',
#                          'data_center': 'POCUMULUS',
#                          'dataset_id': 'PODAAC-GHAM2-2PR8A',
#                          'day_night_flag': 'UNSPECIFIED',
#                          'granule_size': '1.0242048E7',
#                          'id': 'G1226019044-POCUMULUS',
#                          'links': [ { 'href': 's3://podaac-dev-l2ss-samples/20180101073424-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_v08_r29922-v02.0-fv01.0.nc',
#                                       'hreflang': 'en-US',
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'http://data.nodc.noaa.gov/cgi-bin/nph-dods/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://ftp.nodc.noaa.gov/pub/data.nodc/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/IDL/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://suzaku.eorc.jaxa.jp/GCOM_W/w_amsr2/whats_amsr2.html',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://ghrsst.jpl.nasa.gov',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'https://podaac.jpl.nasa.gov/SeaSurfaceTemperature',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://podaac-tools.jpl.nasa.gov/hitide/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/R/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHAM2-2PR8A',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/matlab/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://www.remss.com/missions/amsr/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/python/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'}],
#                          'online_access_flag': True,
#                          'original_format': 'UMM_JSON',
#                          'polygons': [ [ '-74.22 171.81 -71.94 148.49 -69.79 '
#                                          '138.81 -66.95 130.42 -63.4 123.24 '
#                                          '-58.95 116.94 -54.1 111.97 -47.48 '
#                                          '107.01 -35.17 100.7 -19.62 95.36 '
#                                          '6.62 89.13 68.41 77.65 78.55 74.21 '
#                                          '83.9 69.64 85.85 65.49 87.07 60.19 '
#                                          '88.53 41.02 89.13 -17.61 88.42 '
#                                          '-70.04 87.45 -83.52 85.98 -91.12 '
#                                          '83.68 -96 80.02 -99.4 73.84 -102.16 '
#                                          '63.79 -104.74 12.85 -113.95 -9.83 '
#                                          '-118.81 -26.65 -123.58 -39.75 '
#                                          '-128.78 -46.92 -132.69 -53.16 -137.2 '
#                                          '-58.22 -142.13 -62.28 -147.47 -68.66 '
#                                          '-161.1 -72.78 -180 -89.27 -180 -88 '
#                                          '-134.22 -86.44 -125.51 -83.43 '
#                                          '-120.22 -78.08 -116.92 -67.8 -114.05 '
#                                          '-11.42 -104.12 16.09 -98.02 33.61 '
#                                          '-92.4 46.98 -85.86 53.32 -81.31 '
#                                          '58.48 -76.29 62.85 -70.43 66.69 '
#                                          '-63.09 69.49 -55.3 71.89 -45.14 '
#                                          '74.33 -21.85 73.7 5.56 71.97 18.61 '
#                                          '69.53 29.07 66.26 37.97 62.3 45.19 '
#                                          '56.93 51.87 50.63 57.32 36.78 65.01 '
#                                          '18.07 71.39 -9.84 77.73 -70.37 88.55 '
#                                          '-79.38 91.41 -84.28 95.11 -86.49 '
#                                          '99.58 -87.96 107.74 -87.46 107.2 '
#                                          '-86.78 107.65 -84.55 112.84 -79.08 '
#                                          '133.65 -75.67 153.77 -74.22 171.81'],
#                                        [ '-72.78 180 -74.16 163.81 -74.47 '
#                                          '142.46 -76.41 124.18 -82.12 96.85 '
#                                          '-85.44 86.21 -87.44 83.04 -88.28 '
#                                          '86.77 -88.98 104.28 -89.27 180 '
#                                          '-72.78 180']],
#                          'time_end': '2018-01-01T09:12:32.000Z',
#                          'time_start': '2018-01-01T07:34:24.000Z',
#                          'title': '20180101073424-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_v08_r29922-v02.0-fv01.0.nc'},
#                        { 'browse_flag': False,
#                          'collection_concept_id': 'C1225996408-POCUMULUS',
#                          'coordinate_system': 'CARTESIAN',
#                          'data_center': 'POCUMULUS',
#                          'dataset_id': 'PODAAC-GHAM2-2PR8A',
#                          'day_night_flag': 'UNSPECIFIED',
#                          'granule_size': '1.0242048E7',
#                          'id': 'G1226019166-POCUMULUS',
#                          'links': [ { 'href': 's3://podaac-dev-l2ss-samples/20180101190744-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29929-v02.0-fv01.0.nc',
#                                       'hreflang': 'en-US',
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'http://data.nodc.noaa.gov/cgi-bin/nph-dods/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://ftp.nodc.noaa.gov/pub/data.nodc/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/IDL/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://suzaku.eorc.jaxa.jp/GCOM_W/w_amsr2/whats_amsr2.html',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://ghrsst.jpl.nasa.gov',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'https://podaac.jpl.nasa.gov/SeaSurfaceTemperature',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://podaac-tools.jpl.nasa.gov/hitide/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/R/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHAM2-2PR8A',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/matlab/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://www.remss.com/missions/amsr/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/python/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'}],
#                          'online_access_flag': True,
#                          'original_format': 'UMM_JSON',
#                          'polygons': [ [ '-74.21 -1.46 -72.04 -23.96 -69.92 '
#                                          '-33.75 -66.97 -42.57 -63.13 -50.25 '
#                                          '-58.82 -56.26 -53.8 -61.33 -47.43 '
#                                          '-66.07 -34.33 -72.69 -17.51 -78.28 '
#                                          '9.29 -84.45 66.85 -95.03 76.82 '
#                                          '-98.04 82.72 -101.93 86.09 -108.38 '
#                                          '87.97 -121.1 89.125 -180 74.425 -180 '
#                                          '72.23 -155.91 69.98 -145.56 66.92 '
#                                          '-136.58 63.1 -129.1 58.66 -123.05 '
#                                          '52.6 -117.23 45.46 -112.36 32.12 '
#                                          '-106.16 14.74 -100.76 -11.22 -95.05 '
#                                          '-67.9 -85.05 -77.9 -82.27 -83.51 '
#                                          '-78.82 -86.43 -73.65 -87.9 -65.83 '
#                                          '-87.4 -66.26 -86.64 -65.61 -84.74 '
#                                          '-61.18 -79.16 -40.22 -75.68 -19.8 '
#                                          '-74.21 -1.46'],
#                                        [ '89.125 180 87.97 108.97 86.09 96.25 '
#                                          '84.41 92.13 82.01 89.09 76.55 85.8 '
#                                          '67.4 83.03 1.78 70.78 -28.39 62.78 '
#                                          '-40.33 57.89 -49.33 52.67 -56.69 '
#                                          '46.47 -62.03 39.85 -67.44 29.25 '
#                                          '-71.31 15.73 -73.7 -1.74 -74.4 '
#                                          '-29.25 -76.7 -50.58 -82.44 -77.2 '
#                                          '-85.71 -87.33 -87.64 -89.77 -88.55 '
#                                          '-81.87 -89.13 -60.16 -89 30.94 '
#                                          '-87.72 55.24 -86.5 61.28 -84.56 '
#                                          '65.41 -79.57 69.39 -70.1 72.4 -10.41 '
#                                          '83.03 17.18 89.23 34.68 94.98 47.93 '
#                                          '101.69 55.14 107.24 60.68 113.37 '
#                                          '65.19 120.66 68.47 128.47 71.32 '
#                                          '138.92 73.35 151.82 74.425 180 '
#                                          '89.125 180']],
#                          'time_end': '2018-01-01T20:45:52.000Z',
#                          'time_start': '2018-01-01T19:07:44.000Z',
#                          'title': '20180101190744-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29929-v02.0-fv01.0.nc'},
#                        { 'browse_flag': False,
#                          'collection_concept_id': 'C1225996408-POCUMULUS',
#                          'coordinate_system': 'CARTESIAN',
#                          'data_center': 'POCUMULUS',
#                          'dataset_id': 'PODAAC-GHAM2-2PR8A',
#                          'day_night_flag': 'UNSPECIFIED',
#                          'granule_size': '1.0242048E7',
#                          'id': 'G1226019177-POCUMULUS',
#                          'links': [ { 'href': 's3://podaac-dev-l2ss-samples/20180101190744-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_v08_r29929-v02.0-fv01.0.nc',
#                                       'hreflang': 'en-US',
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'http://data.nodc.noaa.gov/cgi-bin/nph-dods/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://ftp.nodc.noaa.gov/pub/data.nodc/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/IDL/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://suzaku.eorc.jaxa.jp/GCOM_W/w_amsr2/whats_amsr2.html',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://ghrsst.jpl.nasa.gov',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'https://podaac.jpl.nasa.gov/SeaSurfaceTemperature',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://podaac-tools.jpl.nasa.gov/hitide/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/R/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHAM2-2PR8A',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/matlab/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://www.remss.com/missions/amsr/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/python/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
# ...
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://ftp.nodc.noaa.gov/pub/data.nodc/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/IDL/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://suzaku.eorc.jaxa.jp/GCOM_W/w_amsr2/whats_amsr2.html',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://ghrsst.jpl.nasa.gov',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'https://podaac.jpl.nasa.gov/SeaSurfaceTemperature',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://podaac-tools.jpl.nasa.gov/hitide/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/R/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHAM2-2PR8A',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/matlab/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://www.remss.com/missions/amsr/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/python/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'}],
#                          'online_access_flag': True,
#                          'original_format': 'UMM_JSON',
#                          'polygons': [ [ '-74.22 12.67 -72.07 -9.88 -69.9 '
#                                          '-19.92 -67.08 -28.4 -63.4 -35.9 '
#                                          '-58.95 -42.2 -53.53 -47.66 -47.65 '
#                                          '-52.02 -34.56 -58.69 -17.31 -64.43 '
#                                          '8.06 -70.3 67.96 -81.39 77.65 -84.51 '
#                                          '83.02 -88.37 86.38 -95.57 88.07 '
#                                          '-108.72 89.12 -180 74.365 -180 74.38 '
#                                          '-164.66 73.43 -150.84 71.69 -139.02 '
#                                          '68.87 -127.94 65.36 -119.27 60.86 '
#                                          '-111.89 55.65 -106 48.87 -100.59 '
#                                          '35.47 -93.58 18.07 -87.75 -9.48 '
#                                          '-81.48 -70.19 -70.63 -79.47 -67.68 '
#                                          '-84.1 -64.24 -86.49 -59.54 -87.96 '
#                                          '-51.37 -87.37 -51.91 -86.7 -51.35 '
#                                          '-84.71 -46.76 -79.14 -25.78 -75.63 '
#                                          '-5.06 -74.22 12.67'],
#                                        [ '89.12 180 88.7 139.61 87.61 118.89 '
#                                          '85.45 108.25 81.36 102.44 76.26 '
#                                          '99.59 67.2 96.89 2.66 84.87 -26.48 '
#                                          '77.33 -38.2 72.8 -48.19 67.35 -55.84 '
#                                          '61.23 -61.53 54.49 -67.4 43.27 '
#                                          '-71.52 28.58 -73.78 11.11 -74.43 '
#                                          '-16.08 -76.59 -36.18 -82.49 -63.69 '
#                                          '-85.68 -73.58 -87.61 -76.1 -88.52 '
#                                          '-68.49 -89.11 -47.72 -89.02 43.7 '
#                                          '-87.75 68.92 -86.53 75.08 -84.68 '
#                                          '79.14 -81.03 82.51 -73.53 85.44 9.28 '
#                                          '101.12 29.92 107.08 45.19 113.93 '
#                                          '52.33 118.74 58.08 124.12 62.55 '
#                                          '129.96 66.35 136.99 69.31 144.96 '
#                                          '71.84 155.45 74.365 180 89.12 180']],
#                          'time_end': '2018-01-02T19:48:16.000Z',
#                          'time_start': '2018-01-02T18:10:08.000Z',
#                          'title': '20180102181008-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29943-v02.0-fv01.0.nc'},
#                        { 'browse_flag': False,
#                          'collection_concept_id': 'C1225996408-POCUMULUS',
#                          'coordinate_system': 'CARTESIAN',
#                          'data_center': 'POCUMULUS',
#                          'dataset_id': 'PODAAC-GHAM2-2PR8A',
#                          'day_night_flag': 'UNSPECIFIED',
#                          'granule_size': '1.0242048E7',
#                          'id': 'G1226019419-POCUMULUS',
#                          'links': [ { 'href': 's3://podaac-dev-l2ss-samples/20180102181008-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_v08_r29943-v02.0-fv01.0.nc',
#                                       'hreflang': 'en-US',
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'http://data.nodc.noaa.gov/cgi-bin/nph-dods/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'https://podaac-opendap.jpl.nasa.gov/opendap/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://ftp.nodc.noaa.gov/pub/data.nodc/ghrsst/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/GDS2/L2P/AMSR2/REMSS/v8a',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/IDL/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://suzaku.eorc.jaxa.jp/GCOM_W/w_amsr2/whats_amsr2.html',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/OceanTemperature/ghrsst/docs/GDS20r5.pdf',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://ghrsst.jpl.nasa.gov',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'https://podaac.jpl.nasa.gov/SeaSurfaceTemperature',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'http://podaac-tools.jpl.nasa.gov/hitide/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/R/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://podaac.jpl.nasa.gov/ws/search/granule/?datasetId=PODAAC-GHAM2-2PR8A',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/matlab/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                     { 'href': 'http://www.remss.com/missions/amsr/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'},
#                                     { 'href': 'ftp://podaac.jpl.nasa.gov/allData/ghrsst/sw/generic_nc_readers/python/',
#                                       'hreflang': 'en-US',
#                                       'inherited': True,
#                                       'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'}],
#                          'online_access_flag': True,
#                          'original_format': 'UMM_JSON',
#                          'polygons': [ [ '-74.22 12.67 -72.07 -9.88 -69.9 '
#                                          '-19.92 -67.08 -28.4 -63.4 -35.9 '
#                                          '-58.95 -42.2 -53.53 -47.66 -47.65 '
#                                          '-52.02 -34.56 -58.69 -17.31 -64.43 '
#                                          '8.06 -70.3 67.96 -81.39 77.65 -84.51 '
#                                          '83.02 -88.37 86.38 -95.57 88.07 '
#                                          '-108.72 89.12 -180 74.365 -180 74.38 '
#                                          '-164.66 73.43 -150.84 71.69 -139.02 '
#                                          '68.87 -127.94 65.36 -119.27 60.86 '
#                                          '-111.89 55.65 -106 48.87 -100.59 '
#                                          '35.47 -93.58 18.07 -87.75 -9.48 '
#                                          '-81.48 -70.19 -70.63 -79.47 -67.68 '
#                                          '-84.1 -64.24 -86.49 -59.54 -87.96 '
#                                          '-51.37 -87.37 -51.91 -86.7 -51.35 '
#                                          '-84.71 -46.76 -79.14 -25.78 -75.63 '
#                                          '-5.06 -74.22 12.67'],
#                                        [ '89.12 180 88.7 139.61 87.61 118.89 '
#                                          '85.45 108.25 81.36 102.44 76.26 '
#                                          '99.59 67.2 96.89 2.66 84.87 -26.48 '
#                                          '77.33 -38.2 72.8 -48.19 67.35 -55.84 '
#                                          '61.23 -61.53 54.49 -67.4 43.27 '
#                                          '-71.52 28.58 -73.78 11.11 -74.43 '
#                                          '-16.08 -76.59 -36.18 -82.49 -63.69 '
#                                          '-85.68 -73.58 -87.61 -76.1 -88.52 '
#                                          '-68.49 -89.11 -47.72 -89.02 43.7 '
#                                          '-87.75 68.92 -86.53 75.08 -84.68 '
#                                          '79.14 -81.03 82.51 -73.53 85.44 9.28 '
#                                          '101.12 29.92 107.08 45.19 113.93 '
#                                          '52.33 118.74 58.08 124.12 62.55 '
#                                          '129.96 66.35 136.99 69.31 144.96 '
#                                          '71.84 155.45 74.365 180 89.12 180']],
#                          'time_end': '2018-01-02T19:48:16.000Z',
#                          'time_start': '2018-01-02T18:10:08.000Z',
#                          'title': '20180102181008-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_v08_r29943-v02.0-fv01.0.nc'}],
#             'id': 'https://cmr.uat.earthdata.nasa.gov:443/search/granules.json',
#             'title': 'ECHO granule metadata',
#             'updated': '2020-05-18T21:41:56.223Z'}}

# %% [markdown]
# ## Curl command line syntax
#
# This command submits the same request as the Python example above, returning search results in JSON format for Granules that share spatial coverage with the input shapefile ([`resources/gulf_shapefile.zip`](resources/gulf_shapefile.zip)) and belong to the target Collection (`echo_collection_id=C1225996408-POCUMULUS`):
#
# ```shell
# curl -XPOST "https://cmr.uat.earthdata.nasa.gov/search/granules.json" -F "shapefile=@resources/gulf_shapefile.zip;type=application/shapefile+zip" -F "echo_collection_id=C1225996408-POCUMULUS" -F "pretty=true"
# ```
#
# The (truncated) results:
#
# ```json
# {
#   "feed" : {
#     "updated" : "2020-05-18T22:09:58.452Z",
#     "id" : "https://cmr.uat.earthdata.nasa.gov:443/search/granules.json",
#     "title" : "ECHO granule metadata",
#     "entry" : [ {
#       "time_start" : "2018-01-01T05:56:16.000Z",
#       "granule_size" : "1.0242048E7",
#       "online_access_flag" : true,
#       "id" : "G1226019017-POCUMULUS",
#       "day_night_flag" : "UNSPECIFIED",
#       "browse_flag" : false,
#       "time_end" : "2018-01-01T07:34:24.000Z",
#       "coordinate_system" : "CARTESIAN",
#       "polygons" : [ [ "-74.21 -163.74 -72.95 -180 -75.43 -180 -74.21 -163.74" ], [ "-72.95 180 -69.22 161.56 -63.56 148.24 -59.74 142.63 -54.76 137.29 -43.19 129.21 -28.81 123 -9.39 117.38 70.28 101.89 78.71 98.84 83.8 94.5 85.75 90.5 87.14 84.43 88.59 63.9 89.12 2.26 88.28 -48.29 87.12 -61.14 85.38 -68.1 82.54 -72.63 77.71 -75.93 63.62 -80.05 9.8 -89.82 -15.54 -95.55 -35.84 -102.3 -50.51 -110.4 -56.3 -115.37 -60.99 -120.88 -64.95 -127.37 -68.22 -135.08 -70.76 -143.97 -72.76 -155.11 -74.35 -180 -89.345 -180 -88.32 -113.33 -86.69 -101.61 -83.86 -95.95 -79.32 -92.73 -70.2 -89.86 -10.6 -79.24 16.19 -73.27 33.1 -67.88 46.23 -61.6 52.76 -57.05 57.86 -52.26 62.64 -46.04 66.5 -38.81 69.5 -30.55 71.71 -21.38 74.26 1.26 73.75 29.71 72.1 42.61 69.64 53.42 66.25 62.72 62.36 69.82 57.32 76.19 51.2 81.62 37.2 89.55 18.32 96.04 -10.4 102.56 -70.39 113.28 -79.49 116.19 -83.94 119.43 -86.33 123.83 -87.89 131.86 -86.97 131.68 -85.71 133.93 -81.4 147.95 -77.84 164.04 -75.43 180 -72.95 180" ], [ "-74.35 180 -74.81 162.65 -77.45 142.63 -82.89 118.89 -85.78 110.18 -87.46 107.84 -88.13 109.51 -88.85 123.7 -89.345 180 -74.35 180" ] ],
#       "original_format" : "UMM_JSON",
#       "collection_concept_id" : "C1225996408-POCUMULUS",
#       "data_center" : "POCUMULUS",
#       "links" : [ {
#         "rel" : "http://esipfed.org/ns/fedsearch/1.1/data#",
#         "hreflang" : "en-US",
#         "href" : "s3://podaac-dev-l2ss-samples/20180101055616-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29921-v02.0-fv01.0.nc"
#       },
#       ...
# ```

# %% [markdown]
# This command gets the same listing again with `curl`, this time returning the search results in their native xml format:
#
# ```shell
# curl -XPOST "https://cmr.uat.earthdata.nasa.gov/search/granules" -F "shapefile=@resources/gulf_shapefile.zip;type=application/shapefile+zip" -F "echo_collection_id=C1225996408-POCUMULUS" -F "pretty=true"
# ```
#
# The (truncated) results:
#
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <results>
#     <hits>1912</hits>
#     <took>970</took>
#     <references>
#         <reference>
#             <name>20180101055616-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29921-v02.0-fv01.0.nc</name>
#             <id>G1226019017-POCUMULUS</id>
#             <location>https://cmr.uat.earthdata.nasa.gov:443/search/concepts/G1226019017-POCUMULUS/1</location>
#             <revision-id>1</revision-id>
#         </reference>
#         <reference>
#             <name>20180101055616-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_v08_r29921-v02.0-fv01.0.nc</name>
#             <id>G1226019025-POCUMULUS</id>
#             <location>https://cmr.uat.earthdata.nasa.gov:443/search/concepts/G1226019025-POCUMULUS/1</location>
#             <revision-id>1</revision-id>
#         </reference>
#         <reference>
#             <name>20180101073424-REMSS-L2P_GHRSST-SSTsubskin-AMSR2-L2B_rt_r29922-v02.0-fv01.0.nc</name>
#             <id>G1226019035-POCUMULUS</id>
#             <location>https://cmr.uat.earthdata.nasa.gov:443/search/concepts/G1226019035-POCUMULUS/1</location>
#             <revision-id>1</revision-id>
#         </reference>
#         ...
# ```
